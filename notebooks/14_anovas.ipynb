# %%
from pathlib import Path
import pandas as pd

import numpy as np
from scipy.spatial.distance import pdist, squareform
from sklearn.preprocessing import StandardScaler

from skbio.stats.distance import permanova
from skbio import DistanceMatrix

# %%
site_metrics = pd.read_csv("../csvs/site_representative_metrics.csv")
site_metrics = site_metrics.set_index('site')
site_metrics = site_metrics.drop(columns=['year_estab', 'years_since_dist', 'elev_mean', 'slope_mean', 'forest_type'])

# Dropping AGG sites as internal variation would be too high
site_metrics = site_metrics[site_metrics['site_type'] != 'AGG']

site_metrics
# Out:
#           site_type  mean__chm  max__chm    sd__chm   cv__chm  mean__crr  \
# site
# EPO_O_04        EPO  38.239886   52.3364  13.330358  0.348752   0.563695
# EPO_O_13        EPO  27.299484   38.0424   6.769295  0.246819   0.590778
# EPO_Y_10        EPO  25.902798   32.9526   5.477748  0.214736   0.611869
# EPO_Y_15        EPO  19.754897   26.8930   4.028354  0.204997   0.534772
# EPO_Y_36        EPO  14.125612   20.8292   4.098733  0.295683   0.520444
# EPO_Y_37        EPO  19.546503   29.8392   5.400514  0.284503   0.518785
# EPY_O_01        EPY  24.300720   30.3114   3.348425  0.137875   0.732646
# EPY_O_07        EPY  19.011238   26.9406   3.608839  0.193783   0.623439
# EPY_O_09        EPY  16.115101   22.3550   3.817097  0.236906   0.740153
# EPY_Y_03        EPY   8.354218   15.0720   3.496191  0.420746   0.670645
# EPY_Y_04        EPY   3.410366    9.7082   2.365638  0.747488   0.479231
# EPY_Y_05        EPY   5.733618   10.5742   1.786667  0.327461   0.545694
# NRM_31          NRM  20.541966   36.1516   6.128783  0.301169   0.634208
# NRM_O_15        NRM  16.994285   28.2112   4.677869  0.276701   0.592710
# NRM_O_19        NRM  23.780320   33.2496   3.748231  0.158180   0.624176
# NRM_Y_39        NRM  14.036899   25.9596   4.591683  0.338734   0.578200
# NRM_Y_41        NRM  17.289280   29.0190   3.841554  0.223302   0.631285
# NRM_Y_69        NRM  19.417583   26.7364   3.670552  0.190833   0.564199
# NRO_138         NRO  27.369721   43.7700   7.470345  0.275386   0.584191
# NRO_174         NRO  21.757273   35.7046   3.857750  0.177105   0.601454
# NRO_190         NRO  29.206860   43.4346   6.485604  0.221705   0.651538
# NRO_52          NRO  32.009452   52.3000  11.851256  0.376098   0.586429
# NRO_O_56        NRO  32.526741   46.0990   7.301614  0.222727   0.634192
# NRO_Y_82        NRO  21.571733   45.3626   4.979545  0.233034   0.594887
# NRY_O_14        NRY   7.848124   19.2144   2.968110  0.379302   0.494390
# NRY_O_20        NRY   6.765479   15.7306   2.576479  0.380251   0.580246
# NRY_O_25        NRY   8.822160   17.1188   2.239719  0.261571   0.648372
# NRY_Y_03        NRY   3.925542   11.8702   2.339601  0.602242   0.553255
# NRY_Y_12        NRY   4.414257   10.0194   1.751777  0.400185   0.486628
# NRY_Y_15        NRY   2.358953    7.2264   1.360831  0.581316   0.439254
# PPO_O_05        PPO  23.460536   33.6042   5.195289  0.222622   0.688433
# PPO_O_09        PPO  29.215378   38.6052   5.715140  0.197247   0.717358
# PPO_O_05                0.977032  ...                    0.272145
# PPO_O_09                2.634790  ...                    0.279840
# PPO_Y_07                2.748619  ...                    0.243907
# PPO_Y_09                0.157633  ...                    0.409874
# PPO_Y_13                1.225434  ...                    0.324007
# PPO_Y_17                0.416655  ...                    0.405433
# PPY_O_09                1.975334  ...                    0.205494
# PPY_O_24               -0.195083  ...                    0.204227
# PPY_O_31                0.828001  ...                    0.234482
# PPY_Y_01                0.983068  ...                    0.450089
# PPY_Y_22                0.372549  ...                    0.454864
# PPY_Y_23               -0.307468  ...                    0.260358
# ULM_147                 0.837654  ...                    0.469468
# ULM_27                  0.402965  ...                    0.346331
# ULM_310                 0.404399  ...                    0.598444
# ULM_325                 0.419146  ...                    0.507379
# ULM_345                 1.351378  ...                    0.474367
# ULM_80                  0.831308  ...                    0.514937
# ULO_107                 1.445625  ...                    0.438452
# ULO_139                 0.426490  ...                    0.526238
# ULO_188                 0.508593  ...                    0.213542
# ULO_237                -0.133164  ...                    0.487096
# ULO_271                 0.917677  ...                    0.418785
# ULY_Y_231               1.402636  ...                    0.561955
# ULY_Y_232               0.619507  ...                    0.699039
# ULY_Y_25                0.853794  ...                    0.589710
# ULY_Y_96                0.708619  ...                    0.715385
#
#            mean__understorey_capture  mean__midstorey_capture  \
# site
# EPO_O_04                    0.206624                 0.717144
# EPO_O_13                    0.267187                 0.000000
# EPO_Y_10                    0.118237                 0.000000
# EPO_Y_15                    0.589193                 0.000000
# EPO_Y_36                    0.431444                 0.000000
# EPO_Y_37                    0.456935                 0.717013
# EPY_O_01                    0.187969                 0.000000
# EPY_O_07                    0.124674                 0.000000
# EPY_O_09                    0.234508                 0.000000
# EPY_Y_03                    0.296513                 0.000000
# EPY_Y_04                    0.201395                 0.000000
# EPY_Y_05                    0.000000                 0.000000
# NRM_31                      0.261335                 0.679702
# NRM_O_15                    0.263090                 0.707436
# NRM_O_19                    0.450380                 0.594839
# NRM_Y_39                    0.790695                 0.000000
# NRM_Y_41                    0.218496                 0.781424
# NRM_Y_69                    0.404446                 0.695577
# NRO_138                     0.183407                 0.691471
# NRO_174                     0.386686                 0.764879
# NRO_190                     0.342336                 0.843818
# NRO_52                      0.779256                 0.296613
# NRO_O_56                    0.590292                 0.569109
# NRO_Y_82                    0.453224                 0.639475
# NRY_O_14                    0.539016                 0.366687
# NRY_O_20                    0.670417                 0.000000
# NRY_O_25                    0.833546                 0.000000
# NRY_Y_03                    0.519030                 0.000000
# NRY_Y_12                    0.384369                 0.000000
# NRY_Y_15                    0.000000                 0.000000
# PPO_O_05                    0.200559                 0.000000
# PPO_O_09                    0.088806                 0.023609
# PPO_Y_07                    0.124824                 0.000000
# PPO_Y_09                    0.200645                 0.349660
# PPO_Y_13                    0.203117                 0.377912
# PPO_Y_17                    0.535959                 0.000000
# PPY_O_09                    0.384476                 0.000000
# PPY_O_24                    0.281617                 0.000000
# PPY_O_31                    0.213853                 0.000000
# PPY_Y_01                    0.000000                 0.000000
# PPY_Y_22                    0.269304                 0.000000
# ULM_80                  0.148905
# ULO_107                 0.137414
# ULO_139                 0.132754
# ULO_188                 0.189815
# ULO_237                 0.166720
# ULO_271                 0.197962
# ULY_Y_231               0.265201
# ULY_Y_232               0.271231
# ULY_Y_25                0.204327
# ULY_Y_96                0.285053
#
# [57 rows x 23 columns]

# %% [markdown]
# # Full Permanova
#
# Start with a PERMANOVA across all groups and all metrics

# %%
y = site_metrics['site_type']
X = site_metrics.drop(columns=['site_type'])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

distances = pdist(X_scaled, metric='euclidean')
distance_matrix = DistanceMatrix(squareform(distances), ids=y.index)

result = permanova(distance_matrix, y, permutations=9999)
result
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      57
# number of groups                 10
# test statistic             6.234324
# p-value                      0.0001
# number of permutations         9999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# Full permanova is highly significant (p < 0.001).
#
# ## Pairwise PERMANOVA

# %%
from itertools import combinations

def pair_wise_permanova(site_pair) -> pd.Series:
    site_a, site_b = site_pair
    mask = (y == site_a) | (y == site_b)

    y_mask = y[mask]
    dm_mask = distance_matrix.filter(y_mask.index)

    result = permanova(dm_mask, y_mask, permutations=9999)
    result.name = (site_a, site_b)
    return result

unique_sites = np.unique(y)
pair_combos = list(combinations(unique_sites, 2))

results = map(pair_wise_permanova, pair_combos)
permanova_df = pd.DataFrame(results)

def get_p_val_group(p_val: float):
    if p_val < 0.001:
        significant = 'highly significant (p < 0.001)'
    elif p_val < 0.01:
        significant = 'very significant (p < 0.01)'
    elif p_val < 0.05:
        significant = 'significant (p < 0.05)'
    else:
        significant = 'not significant (p >= 0.5)'
    return significant

permanova_df['p_val_group'] = permanova_df['p-value'].apply(get_p_val_group)
permanova_df
# Out:
#         method name test statistic name  sample size  number of groups  \
# EPO EPY   PERMANOVA            pseudo-F           12                 2
#     NRM   PERMANOVA            pseudo-F           12                 2
#     NRO   PERMANOVA            pseudo-F           12                 2
#     NRY   PERMANOVA            pseudo-F           12                 2
#     PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# EPY NRM   PERMANOVA            pseudo-F           12                 2
#     NRO   PERMANOVA            pseudo-F           12                 2
#     NRY   PERMANOVA            pseudo-F           12                 2
#     PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# NRM NRO   PERMANOVA            pseudo-F           12                 2
#     NRY   PERMANOVA            pseudo-F           12                 2
#     PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# NRO NRY   PERMANOVA            pseudo-F           12                 2
#     PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# NRY PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# PPO PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# PPY ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# ULM ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# ULO ULY   PERMANOVA            pseudo-F            9                 2
#
#          test statistic  p-value  number of permutations  \
# EPO EPY        3.454328   0.0027                    9999
#     NRM        3.484436   0.0099                    9999
#     NRO        4.244638   0.0081                    9999
#     NRY        3.765525   0.0020                    9999
#     PPO        4.007530   0.0114                    9999
#     PPY        3.802077   0.0025                    9999
#     ULM        8.162522   0.0022                    9999
#     ULO        2.730503   0.0346                    9999
#     ULY        8.392784   0.0051                    9999
# EPY NRM        5.837909   0.0020                    9999
#     NRO        8.319193   0.0032                    9999
#     NRY        2.588367   0.0401                    9999
#     PPO        2.134541   0.0938                    9999
#     PPY        0.535985   0.6820                    9999
#     ULM       12.079215   0.0026                    9999
#     ULO        4.892767   0.0022                    9999
#     ULY        7.954546   0.0107                    9999
# NRM NRO        1.967150   0.0669                    9999
#     NRY        6.316140   0.0045                    9999
#     PPO        4.401630   0.0031                    9999
#     PPY        5.266944   0.0020                    9999
#     ULM       10.344482   0.0024                    9999
#     ULO        3.973403   0.0024                    9999
#     ULY       17.985872   0.0048                    9999
# NRO NRY        9.198337   0.0024                    9999
#     PPO        5.798799   0.0020                    9999
#     PPY        7.569326   0.0028                    9999
#     ULM        5.210206   0.0116                    9999
#     ULO        2.073862   0.0677                    9999
#     ULY       16.576598   0.0061                    9999
# NRY PPO        5.910053   0.0041                    9999
#     PPY        2.179070   0.0868                    9999
#     ULM       12.807482   0.0024                    9999
#     ULO        6.762817   0.0021                    9999
#     ULY        6.619185   0.0054                    9999
# PPO PPY        1.720167   0.1688                    9999
#     ULM       10.383252   0.0019                    9999
#     ULO        3.603655   0.0157                    9999
#     ULY       12.815373   0.0041                    9999
# PPY ULM       11.530939   0.0018                    9999
#     ULO        4.884032   0.0043                    9999
#     ULY        8.097439   0.0042                    9999
# ULM ULO        3.577684   0.0127                    9999
#     ULY       11.755242   0.0048                    9999
# ULO ULY       10.484684   0.0084                    9999
#
#                          p_val_group
# EPO EPY  very significant (p < 0.01)
#     NRM  very significant (p < 0.01)
#     NRO  very significant (p < 0.01)
#     NRY  very significant (p < 0.01)
#     PPO       significant (p < 0.05)
#     PPY  very significant (p < 0.01)
#     ULM  very significant (p < 0.01)
#     ULO       significant (p < 0.05)
#     ULY  very significant (p < 0.01)
# EPY NRM  very significant (p < 0.01)
#     NRO  very significant (p < 0.01)
#     NRY       significant (p < 0.05)
#     PPO   not significant (p >= 0.5)
#     PPY   not significant (p >= 0.5)
#     ULM  very significant (p < 0.01)
#     ULO  very significant (p < 0.01)
#     ULY       significant (p < 0.05)
# NRM NRO   not significant (p >= 0.5)
#     NRY  very significant (p < 0.01)
#     PPO  very significant (p < 0.01)
#     PPY  very significant (p < 0.01)
#     ULM  very significant (p < 0.01)
#     ULO  very significant (p < 0.01)
#     ULY  very significant (p < 0.01)
# NRO NRY  very significant (p < 0.01)
#     PPO  very significant (p < 0.01)
#     PPY  very significant (p < 0.01)
#     ULM       significant (p < 0.05)
#     ULO   not significant (p >= 0.5)
#     ULY  very significant (p < 0.01)
# NRY PPO  very significant (p < 0.01)
#     PPY   not significant (p >= 0.5)
#     ULM  very significant (p < 0.01)
#     ULO  very significant (p < 0.01)
#     ULY  very significant (p < 0.01)
# PPO PPY   not significant (p >= 0.5)
#     ULM  very significant (p < 0.01)
#     ULO       significant (p < 0.05)
#     ULY  very significant (p < 0.01)
# PPY ULM  very significant (p < 0.01)
#     ULO  very significant (p < 0.01)
#     ULY  very significant (p < 0.01)
# ULM ULO       significant (p < 0.05)
#     ULY  very significant (p < 0.01)
# ULO ULY  very significant (p < 0.01)

# %%
permanova_df.reset_index().rename(columns= { "level_0": "site_type_a", "level_1": "site_type_b" }).to_csv("../csvs/pairwise-permanova-result.csv")

# %% [markdown]
# Pairwise permanova is ..
#
# ## Per metric analysis
#
# - Kruskall Wallis test to test amongs multiple groups
# - Post hoc dunns test to do pairwise

# %%
from scipy.stats import kruskal
import pandas as pd

# Perform Kruskal-Wallis test for each metric
kruskal_results = []

for metric in X.columns:
    # Group the metric values by site_type
    groups = [X.loc[y == site_type, metric].values for site_type in np.unique(y)]
    
    # Remove any groups that are empty or have insufficient data
    groups = [group for group in groups if len(group) > 0]
    
    if len(groups) >= 2:  # Need at least 2 groups for comparison
        # Perform Kruskal-Wallis test
        statistic, p_value = kruskal(*groups)
        
        kruskal_results.append({
            'metric': metric,
            'statistic': statistic,
            'p_value': p_value,
            'significant': 'Yes' if p_value < 0.05 else 'No',
            "p_val_group": get_p_val_group(p_value)
        })

# Convert to DataFrame
kruskal_df = pd.DataFrame(kruskal_results)
kruskal_df = kruskal_df.sort_values('p_value')  # Sort by p-value
print(f"Kruskal-Wallis test results for {len(kruskal_df)} metrics:")
kruskal_df
# Out:
# Kruskal-Wallis test results for 22 metrics:
#                         metric  statistic       p_value significant  \
# 2                      sd__chm  45.740956  6.726837e-07         Yes
# 1                     max__chm  44.810224  1.000304e-06         Yes
# 14     mean__midstorey_capture  36.358579  3.423837e-05         Yes
# 18       sd__midstorey_capture  36.346820  3.440359e-05         Yes
# 0                    mean__chm  36.018875  3.934200e-05         Yes
# 15   mean__upperstorey_capture  34.490200  7.326634e-05         Yes
# 20     mean__canopy_cover_gt1m  32.127465  1.892736e-04         Yes
# 21       sd__canopy_cover_gt1m  30.488990  3.620922e-04         Yes
# 8        mean__veg_height_kurt  30.397157  3.754066e-04         Yes
# 5                    mean__fhd  30.379189  3.780671e-04         Yes
# 6          mean__veg_height_cv  30.305082  3.892370e-04         Yes
# 7        cv__veg_height_median  30.123291  4.180236e-04         Yes
# 16    sd__groundstorey_capture  28.967756  6.562062e-04         Yes
# 3                      cv__chm  27.701875  1.069617e-03         Yes
# 4                    mean__crr  27.337992  1.229534e-03         Yes
# 12  mean__groundstorey_capture  26.662311  1.590386e-03         Yes
# 11                   mean__vci  26.262553  1.850314e-03         Yes
# 9                      sd__crr  25.326195  2.630760e-03         Yes
# 10                     sd__vci  25.052329  2.913837e-03         Yes
# 17     sd__understorey_capture  23.880516  4.494264e-03         Yes
# 13   mean__understorey_capture  22.835410  6.576736e-03         Yes
# 19     sd__upperstorey_capture   7.262432  6.098170e-01          No
#
#                        p_val_group
# 2   highly significant (p < 0.001)
# 1   highly significant (p < 0.001)
# 14  highly significant (p < 0.001)
# 18  highly significant (p < 0.001)
# 0   highly significant (p < 0.001)
# 15  highly significant (p < 0.001)
# 20  highly significant (p < 0.001)
# 21  highly significant (p < 0.001)
# 8   highly significant (p < 0.001)
# 5   highly significant (p < 0.001)
# 6   highly significant (p < 0.001)
# 7   highly significant (p < 0.001)
# 16  highly significant (p < 0.001)
# 3      very significant (p < 0.01)
# 4      very significant (p < 0.01)
# 12     very significant (p < 0.01)
# 11     very significant (p < 0.01)
# 9      very significant (p < 0.01)
# 10     very significant (p < 0.01)
# 17     very significant (p < 0.01)
# 13     very significant (p < 0.01)
# 19      not significant (p >= 0.5)

# %%
import scikit_posthocs as sp

results = {}
flattenend_results = []

for metric in kruskal_df[kruskal_df['significant'] == 'Yes']['metric']:
    res = sp.posthoc_dunn(site_metrics, val_col=metric, group_col='site_type')
    results[metric] = res

    # Only take upper triangle to avoid duplicates (since matrix is symmetric)
    for i_idx, i in enumerate(res.index):
        for j_idx, j in enumerate(res.columns):
            if i_idx < j_idx:  # Only upper triangle (i_idx < j_idx avoids diagonal and lower triangle)
                flattenend_results.append({
                    "site_type_a": i,
                    "site_type_b": j,
                    "metric": metric,
                    "p_val": res.loc[i, j],
                    "p_val_group": get_p_val_group(res.loc[i, j] )
                })

flattenend_results = pd.DataFrame(flattenend_results)
flattenend_results.to_csv("../csvs/dunss_test_pairwise_per_metric.csv")
results['cv__chm']
# Out:
#           EPO       EPY       NRM       NRO       NRY       PPO       PPY  \
# EPO  1.000000  0.651131  0.767487  0.767487  0.051427  0.454548  0.519898
# EPY  0.651131  1.000000  0.454548  0.454548  0.134730  0.230122  0.848281
# NRM  0.767487  0.454548  1.000000  1.000000  0.024861  0.651131  0.347646
# NRO  0.767487  0.454548  1.000000  1.000000  0.024861  0.651131  0.347646
# NRY  0.051427  0.134730  0.024861  0.024861  1.000000  0.007023  0.192098
# PPO  0.454548  0.230122  0.651131  0.651131  0.007023  1.000000  0.164117
# PPY  0.519898  0.848281  0.347646  0.347646  0.192098  0.164117  1.000000
# ULM  0.011110  0.036885  0.004584  0.004584  0.554302  0.001012  0.057997
# ULO  0.537319  0.852660  0.368772  0.368772  0.214836  0.183544  0.997354
# ULY  0.003811  0.012813  0.001589  0.001589  0.249678  0.000368  0.020459
#
#           ULM       ULO       ULY
# EPO  0.011110  0.537319  0.003811
# EPY  0.036885  0.852660  0.012813
# NRM  0.004584  0.368772  0.001589
# NRO  0.004584  0.368772  0.001589
# NRY  0.554302  0.214836  0.249678
# PPO  0.001012  0.183544  0.000368
# PPY  0.057997  0.997354  0.020459
# ULM  1.000000  0.071202  0.533788
# ULO  0.071202  1.000000  0.025925
# ULY  0.533788  0.025925  1.000000

# %%
significant_results = flattenend_results[flattenend_results['p_val'] < 0.05]
significant_results
# Out:
#     site_type_a site_type_b                     metric     p_val  \
# 0           EPO         EPY                    sd__chm  0.049380
# 3           EPO         NRY                    sd__chm  0.007023
# 5           EPO         PPY                    sd__chm  0.003480
# 10          EPY         NRO                    sd__chm  0.029705
# 14          EPY         ULM                    sd__chm  0.000161
# ..          ...         ...                        ...       ...
# 925         NRO         PPO  mean__understorey_capture  0.032391
# 930         NRY         PPO  mean__understorey_capture  0.016767
# 931         NRY         PPY  mean__understorey_capture  0.027776
# 936         PPO         ULM  mean__understorey_capture  0.001075
# 939         PPY         ULM  mean__understorey_capture  0.002078
#
#                         p_val_group
# 0            significant (p < 0.05)
# 3       very significant (p < 0.01)
# 5       very significant (p < 0.01)
# 10           significant (p < 0.05)
# 14   highly significant (p < 0.001)
# ..                              ...
# 925          significant (p < 0.05)
# 930          significant (p < 0.05)
# 931          significant (p < 0.05)
# 936     very significant (p < 0.01)
# 939     very significant (p < 0.01)
#
# [314 rows x 5 columns]

# %%
from cliffs_delta import cliffs_delta

# Calculate Cliff's Delta for all significant results
sig_res_with_cliffs = []

for _, row in significant_results.iterrows():
    metric = row['metric']
    site_a = row['site_type_a']
    site_b = row['site_type_b']
    p_val = row['p_val']
    
    # Get the data for each group
    group_a_data = X.loc[y == site_a, metric].values
    group_b_data = X.loc[y == site_b, metric].values
    
    # Calculate Cliff's Delta
    delta, magnitude = cliffs_delta(group_a_data, group_b_data)
    
    sig_res_with_cliffs.append({
        'metric': metric,
        'site_type_a': site_a,
        'site_type_b': site_b,
        'p_val': p_val,
        'p_val_group': row['p_val_group'],
        'cliffs_delta': delta,
        'effect_size': magnitude,
        'mean_a': np.mean(group_a_data),
        'mean_b': np.mean(group_b_data),
        'n_a': len(group_a_data),
        'n_b': len(group_b_data)
    })
    
# Convert to DataFrame
cliffs_delta_df = pd.DataFrame(sig_res_with_cliffs)

# Sort by absolute effect size (largest effects first)
cliffs_delta_df['abs_cliffs_delta'] = abs(cliffs_delta_df['cliffs_delta'])
cliffs_delta_df = cliffs_delta_df.sort_values('abs_cliffs_delta', ascending=False)

cliffs_delta_df.to_csv("../csvs/significant_dunns_results_with_cliffs_delta.csv")
cliffs_delta_df.drop('abs_cliffs_delta', axis=1)
# Out:
#                         metric site_type_a site_type_b     p_val  \
# 0                      sd__chm         EPO         EPY  0.049380
# 174        mean__veg_height_cv         EPO         PPY  0.000840
# 161                  mean__fhd         NRO         NRY  0.001374
# 163                  mean__fhd         NRO         ULY  0.005109
# 164                  mean__fhd         NRY         PPO  0.006665
# ..                         ...         ...         ...       ...
# 278                    sd__crr         PPY         ULM  0.036885
# 310  mean__understorey_capture         NRY         PPO  0.016767
# 156                  mean__fhd         EPY         NRO  0.047403
# 229                  mean__crr         EPY         NRY  0.047403
# 157                  mean__fhd         EPY         ULM  0.045492
#
#                         p_val_group  cliffs_delta effect_size    mean_a  \
# 0            significant (p < 0.05)      1.000000       large  6.517501
# 174  highly significant (p < 0.001)      1.000000       large  0.662658
# 161     very significant (p < 0.01)      1.000000       large  2.133752
# 163     very significant (p < 0.01)      1.000000       large  2.133752
# 164     very significant (p < 0.01)     -1.000000       large  1.432872
# ..                              ...           ...         ...       ...
# 278          significant (p < 0.05)     -0.555556       large  0.127794
# 310          significant (p < 0.05)      0.555556       large  0.491063
# 156          significant (p < 0.05)     -0.555556       large  1.683919
# 229          significant (p < 0.05)      0.500000       large  0.631968
# 157          significant (p < 0.05)     -0.500000       large  1.683919
#
#        mean_b  n_a  n_b
# 0    3.070476    6    6
# 174  0.396539    6    6
# 161  1.432872    6    6
# 163  1.458746    6    4
# 164  2.080042    6    6
# ..        ...  ...  ...
# 278  0.161118    6    6
# 310  0.225652    6    6
# 156  2.133752    6    6
# 229  0.533691    6    6
# 157  2.139647    6    6
#
# [314 rows x 11 columns]

# %%
import scikit_posthocs as sp

results = {}
flattenend_results = []

for metric in kruskal_df[kruskal_df['significant'] == 'Yes']['metric']:
    res = sp.posthoc_dunn(site_metrics, val_col=metric, group_col='site_type', p_adjust='holm')
    results[metric] = res

    # Only take upper triangle to avoid duplicates (since matrix is symmetric)
    for i_idx, i in enumerate(res.index):
        for j_idx, j in enumerate(res.columns):
            if i_idx < j_idx:  # Only upper triangle (i_idx < j_idx avoids diagonal and lower triangle)
                flattenend_results.append({
                    "site_type_a": i,
                    "site_type_b": j,
                    "metric": metric,
                    "p_val": res.loc[i, j],
                    "p_val_group": get_p_val_group(res.loc[i, j] )
                })

flattenend_results = pd.DataFrame(flattenend_results)
flattenend_results.to_csv("../csvs/dunss_test_pairwise_per_metric_holm.csv")
results['cv__chm']
# Out:
#           EPO       EPY       NRM       NRO       NRY       PPO       PPY  \
# EPO  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# EPY  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# NRM  1.000000  1.000000  1.000000  1.000000  0.845258  1.000000  1.000000
# NRO  1.000000  1.000000  1.000000  1.000000  0.845258  1.000000  1.000000
# NRY  1.000000  1.000000  0.845258  0.845258  1.000000  0.266872  1.000000
# PPO  1.000000  1.000000  1.000000  1.000000  0.266872  1.000000  1.000000
# PPY  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ULM  0.411062  1.000000  0.183366  0.183366  1.000000  0.044542  1.000000
# ULO  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ULY  0.156256  0.461255  0.068346  0.068346  1.000000  0.016544  0.716067
#
#           ULM       ULO       ULY
# EPO  0.411062  1.000000  0.156256
# EPY  1.000000  1.000000  0.461255
# NRM  0.183366  1.000000  0.068346
# NRO  0.183366  1.000000  0.068346
# NRY  1.000000  1.000000  1.000000
# PPO  0.044542  1.000000  0.016544
# PPY  1.000000  1.000000  0.716067
# ULM  1.000000  1.000000  1.000000
# ULO  1.000000  1.000000  0.845258
# ULY  1.000000  0.845258  1.000000

# %%
significant_results = flattenend_results[flattenend_results['p_val'] < 0.05]
significant_results
# Out:
#     site_type_a site_type_b                     metric     p_val  \
# 14          EPY         ULM                    sd__chm  0.006746
# 32          NRY         ULM                    sd__chm  0.000293
# 33          NRY         ULO                    sd__chm  0.036834
# 34          NRY         ULY                    sd__chm  0.011870
# 39          PPY         ULM                    sd__chm  0.000101
# ..          ...         ...                        ...       ...
# 788         NRM         ULY                    sd__crr  0.015590
# 833         NRM         ULY                    sd__vci  0.045075
# 869         EPY         ULM    sd__understorey_capture  0.036563
# 914         EPY         ULM  mean__understorey_capture  0.015783
# 936         PPO         ULM  mean__understorey_capture  0.047284
#
#                         p_val_group
# 14      very significant (p < 0.01)
# 32   highly significant (p < 0.001)
# 33           significant (p < 0.05)
# 34           significant (p < 0.05)
# 39   highly significant (p < 0.001)
# ..                              ...
# 788          significant (p < 0.05)
# 833          significant (p < 0.05)
# 869          significant (p < 0.05)
# 914          significant (p < 0.05)
# 936          significant (p < 0.05)
#
# [65 rows x 5 columns]

# %%
# Calculate Cliff's Delta for all significant results
sig_res_with_cliffs = []

for _, row in significant_results.iterrows():
    metric = row['metric']
    site_a = row['site_type_a']
    site_b = row['site_type_b']
    p_val = row['p_val']
    
    # Get the data for each group
    group_a_data = X.loc[y == site_a, metric].values
    group_b_data = X.loc[y == site_b, metric].values
    
    # Calculate Cliff's Delta
    delta, magnitude = cliffs_delta(group_a_data, group_b_data)
    
    sig_res_with_cliffs.append({
        'metric': metric,
        'site_type_a': site_a,
        'site_type_b': site_b,
        'p_val': p_val,
        'p_val_group': row['p_val_group'],
        'cliffs_delta': delta,
        'effect_size': magnitude,
        'mean_a': np.mean(group_a_data),
        'mean_b': np.mean(group_b_data),
        'n_a': len(group_a_data),
        'n_b': len(group_b_data)
    })
    
# Convert to DataFrame
cliffs_delta_df = pd.DataFrame(sig_res_with_cliffs)

# Sort by absolute effect size (largest effects first)
cliffs_delta_df['abs_cliffs_delta'] = abs(cliffs_delta_df['cliffs_delta'])
cliffs_delta_df = cliffs_delta_df.sort_values('abs_cliffs_delta', ascending=False)

cliffs_delta_df.to_csv("../csvs/significant_dunns_results_with_cliffs_delta_holm.csv")
cliffs_delta_df.drop('abs_cliffs_delta', axis=1)
# Out:
#                        metric site_type_a site_type_b     p_val  \
# 0                     sd__chm         EPY         ULM  0.006746
# 46      cv__veg_height_median         EPY         ULY  0.040921
# 31    mean__canopy_cover_gt1m         EPY         NRO  0.010207
# 1                     sd__chm         NRY         ULM  0.000293
# 34    mean__canopy_cover_gt1m         NRO         ULY  0.013938
# ..                        ...         ...         ...       ...
# 33    mean__canopy_cover_gt1m         NRO         NRY  0.039014
# 62    sd__understorey_capture         EPY         ULM  0.036563
# 64  mean__understorey_capture         PPO         ULM  0.047284
# 48      cv__veg_height_median         PPO         ULM  0.038450
# 53                    cv__chm         PPO         ULM  0.044542
#
#                        p_val_group  cliffs_delta effect_size    mean_a  \
# 0      very significant (p < 0.01)     -1.000000       large  3.070476
# 46          significant (p < 0.05)     -1.000000       large  0.470111
# 31          significant (p < 0.05)     -1.000000       large  0.592883
# 1   highly significant (p < 0.001)     -1.000000       large  2.206086
# 34          significant (p < 0.05)      1.000000       large  0.908020
# ..                             ...           ...         ...       ...
# 33          significant (p < 0.05)      0.944444       large  0.908020
# 62          significant (p < 0.05)     -0.888889       large  0.167024
# 64          significant (p < 0.05)     -0.888889       large  0.225652
# 48          significant (p < 0.05)     -0.833333       large  0.336437
# 53          significant (p < 0.05)     -0.777778       large  0.238687
#
#        mean_b  n_a  n_b
# 0   15.568905    6    6
# 46   1.439095    6    4
# 31   0.908020    6    6
# 1   15.568905    6    6
# 34   0.510249    6    4
# ..        ...  ...  ...
# 33   0.611700    6    6
# 62   0.300363    6    6
# 64   0.590667    6    6
# 48   0.672758    6    6
# 53   0.521196    6    6
#
# [65 rows x 11 columns]
