# %%
import pandas as pd
import numpy as np

# %%
site_info = pd.read_csv("../data/source/environmental_data__site_information.csv")
site_info = site_info.rename(columns={
    "Master_ID": "site",
    "Class": "site_type",
    "Disturbance": "disturbance",
    "Estabyear": "year"
})
site_info = site_info[['site', 'site_type', 'disturbance', 'year']]
site_info['year'] = site_info['year'].fillna(-9999).astype('int')

# Add site_number column: sequential numbering of unique site_ids within each site_type
site_info['site_number'] = site_info.groupby('site_type')['site'].transform(
    lambda x: pd.factorize(x)[0] + 1
)
site_info = site_info.set_index('site')
site_info
# Out:
#           site_type  disturbance  year  site_number
# site
# AGG_O_01        AGG            8  2011            1
# AGG_O_05        AGG            8  2011            2
# AGG_O_07        AGG            8  2013            3
# AGG_Y_02        AGG            8  2019            4
# AGG_Y_03        AGG            8  2019            5
# ...             ...          ...   ...          ...
# ULY_Y_01        ULY            9  2016            2
# ULY_Y_231       ULY            9  2018            3
# ULY_Y_232       ULY            9  2019            4
# ULY_Y_25        ULY            9  2019            5
# ULY_Y_96        ULY            9  2018            6
#
# [66 rows x 4 columns]

# %%
plot_metrics = pd.read_parquet("../data/outputs/plots/plot_metrics.parquet")
plot_metrics['plot_number'] = plot_metrics.index.str[-1].astype(int)
plot_metrics
# Out:
#                    max       min      range      mean    median        sd  \
# plot
# AGG_O_01_P1  16.275999  0.000000  16.275999  4.428016  4.555000  4.093416
# AGG_O_01_P1  16.275999  0.000000  16.275999  6.716327  7.568000  3.647536
# AGG_O_01_P1  16.275999  0.000000  16.275999  4.428016  4.555000  4.093416
# AGG_O_01_P1  16.275999  0.000000  16.275999  4.428016  4.555000  4.093416
# AGG_O_01_P1  16.275999  0.001000  16.275000  5.646877  6.400000  3.805994
# ...                ...       ...        ...       ...       ...       ...
# ULY_Y_96_P5   1.277456  6.454628   1.294826  1.519432  2.150591  1.458456
# ULY_Y_96_P5   1.273690  8.157261   1.284342  1.545650  2.531208  1.467207
# ULY_Y_96_P5   1.273690  8.157261   1.284342  1.545650  2.531208  1.467207
# ULY_Y_96_P5   1.266414  3.705982   1.307232  1.437641  2.025826  1.486969
# ULY_Y_96_P5   1.200145  1.982114   1.420801  1.314224  1.571348  1.549403
#
#                    var        cv       crr      skew  ...  cv_inside  \
# ...

# %%
plot_metrics_with_site_info = plot_metrics.join(site_info.drop(columns='site_type'), on='site')
plot_metrics_with_site_info
# Out:
#                    max       min      range      mean    median        sd  \
# plot
# AGG_O_01_P1  16.275999  0.000000  16.275999  4.428016  4.555000  4.093416
# AGG_O_01_P1  16.275999  0.000000  16.275999  6.716327  7.568000  3.647536
# AGG_O_01_P1  16.275999  0.000000  16.275999  4.428016  4.555000  4.093416
# AGG_O_01_P1  16.275999  0.000000  16.275999  4.428016  4.555000  4.093416
# AGG_O_01_P1  16.275999  0.001000  16.275000  5.646877  6.400000  3.805994
# ...                ...       ...        ...       ...       ...       ...
# ULY_Y_96_P5   1.277456  6.454628   1.294826  1.519432  2.150591  1.458456
# ULY_Y_96_P5   1.273690  8.157261   1.284342  1.545650  2.531208  1.467207
# ULY_Y_96_P5   1.273690  8.157261   1.284342  1.545650  2.531208  1.467207
# ULY_Y_96_P5   1.266414  3.705982   1.307232  1.437641  2.025826  1.486969
# ULY_Y_96_P5   1.200145  1.982114   1.420801  1.314224  1.571348  1.549403
#
# ...

# %%
plot_metrics_with_site_info.to_parquet("../data/outputs/plots/plot_metrics_with_site_info.parquet")
