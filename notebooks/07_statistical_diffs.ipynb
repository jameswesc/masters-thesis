# %%
from pathlib import Path
import pandas as pd

import numpy as np
from scipy.spatial.distance import pdist, squareform
from sklearn.preprocessing import StandardScaler

from skbio.stats.distance import permanova
from skbio import DistanceMatrix

# %%
site_metrics = pd.read_csv("../csvs/site_representative_metrics.csv")
site_metrics = site_metrics.set_index('site')
site_metrics['site_type'] = site_metrics.index.str[0:3]
# site_metrics = site_metrics.drop(columns=['year_estab', 'years_since_dist', 'elev_mean', 'slope_mean', 'forest_type'])

# Dropping AGG sites as internal variation would be too high
# site_metrics = site_metrics[site_metrics['site_type'] != 'AGG']

site_metrics
# Out:
#            mean__chm  max__chm  mean__veg_height_q30  mean__canopy_cover_gt1m  \
# site
# EPO_O_04   38.239886   52.3364             11.945576                 0.868069
# EPO_O_13   27.299484   38.0424             11.010423                 0.685449
# EPO_Y_10   25.902798   32.9526             12.544017                 0.652079
# EPO_Y_15   19.754897   26.8930              5.932556                 0.774936
# EPO_Y_36   14.125612   20.8292              4.015971                 0.684135
# EPO_Y_37   19.546503   29.8392              6.103131                 0.900535
# EPY_O_01   24.300720   30.3114             16.589948                 0.723886
# EPY_O_07   19.011238   26.9406              9.426508                 0.723917
# EPY_O_09   16.115101   22.3550             11.017379                 0.624741
# EPY_Y_03    8.354218   15.0720              4.985573                 0.533897
# EPY_Y_04    3.410366    9.7082              1.037286                 0.303691
# EPY_Y_05    5.733618   10.5742              2.323151                 0.647168
# NRM_31     20.541966   36.1516             10.334790                 0.850813
# NRM_O_15   16.994285   28.2112              6.648945                 0.864803
# NRM_O_19   23.780320   33.2496             10.400958                 0.891114
# NRM_Y_39   14.036899   25.9596              5.116465                 0.863789
# NRM_Y_41   17.289280   29.0190              7.993634                 0.900241
# NRM_Y_69   19.417583   26.7364              7.428470                 0.895895
# NRO_138    27.369721   43.7700             10.508378                 0.847834
# NRO_174    21.757273   35.7046              8.919786                 0.924231
# NRO_190    29.206860   43.4346             13.948580                 0.951621
# NRO_52     32.009452   52.3000             12.475994                 0.903800
# NRO_O_56   32.526741   46.0990             14.499455                 0.927315
# NRO_Y_82   21.571733   45.3626              8.451736                 0.893320
# NRY_O_14    7.848124   19.2144              2.072371                 0.704392
# NRY_O_20    6.765479   15.7306              2.937663                 0.727715
# NRY_O_25    8.822160   17.1188              4.659792                 0.880973
# NRY_Y_03    3.925542   11.8702              1.678545                 0.592182
# NRY_Y_12    4.414257   10.0194              1.276375                 0.480389
# NRY_Y_15    2.358953    7.2264              0.611329                 0.284545
# PPO_O_05   23.460536   33.6042             14.260222                 0.817567
# PPO_O_09   29.215378   38.6052             19.434661                 0.820449
# PPO_Y_07   21.553197   27.9720             16.162502                 0.917400
# PPO_Y_09   15.007683   27.7054              7.153888                 0.666726
# PPO_Y_13   15.935400   20.9804             10.485720                 0.869614
# PPO_Y_17   13.895853   20.7816              7.814067                 0.829060
# PPY_O_09   14.594996   19.5496             10.690535                 0.921443
# PPY_O_24    5.593535   11.7314              2.456117                 0.503527
# PPY_O_31   13.429151   19.0670              8.223733                 0.867034
# PPY_Y_01    3.992488    8.2248              2.115015                 0.759533
# PPY_Y_22    5.528301   10.6260              2.618003                 0.789601
# PPY_Y_23    2.083002    5.3198              0.871775                 0.266976
# ULM_147    49.118621   79.8704             21.584595                 0.927847
# ULM_27     23.640164   50.9246             11.468868                 0.853902
# ULM_310    27.153579   54.2058             10.221095                 0.862755
# ULM_325    28.955089   70.6828             12.994021                 0.934009
# ULM_345    30.493859   68.6768             15.286463                 0.924986
# ULM_80     23.001945   50.1174             11.454192                 0.885391
# ULO_107    26.872410   50.5858             15.427485                 0.892017
# ULO_139    29.672216   52.0878             15.599757                 0.894059
# ULO_188    24.101058   43.7208             13.370056                 0.815370
# ULO_237    36.795973   49.8486             15.792681                 0.734757
# ULO_271    21.914483   36.3238             11.180012                 0.721113
# ULY_Y_231  25.492242   49.5954              6.565805                 0.548123
# ULY_Y_232  12.777133   52.2856              2.544358                 0.439321
# ULY_Y_25   31.919078   54.6412              6.629034                 0.721464
# ULY_Y_96    5.547715   26.7056              1.372181                 0.332088
#
#            mean__fhd  mean__veg_height_cv  mean__vci  mean__crr  \
# site
# EPO_O_04    2.177094             0.620750   0.546357   0.563695
# EPO_O_13    1.972776             0.661154   0.536631   0.590778
# EPO_Y_10    2.086827             0.640253   0.588872   0.611869
# EPO_Y_15    2.093690             0.693868   0.624400   0.534772
# EPO_Y_36    1.622504             0.758431   0.523706   0.520444
# EPO_Y_37    2.201588             0.601493   0.638667   0.518785
# EPY_O_01    2.102990             0.394931   0.608015   0.732646
# EPY_O_07    2.326841             0.459757   0.694907   0.623439
# EPY_O_09    1.597490             0.379940   0.500202   0.740153
# EPY_Y_03    1.355165             0.390761   0.480407   0.670645
# EPY_Y_04    1.121583             0.699650   0.463484   0.479231
# EPY_Y_05    1.599443             0.437543   0.634663   0.545694
# NRM_31      2.140198             0.412651   0.590782   0.634208
# NRM_O_15    2.032225             0.529249   0.596453   0.592710
# NRM_O_19    2.266997             0.490119   0.637992   0.624176
# NRM_Y_39    1.987496             0.548493   0.596416   0.578200
# NRM_Y_41    2.042675             0.407848   0.591152   0.631285
# NRM_Y_69    2.361924             0.512377   0.705931   0.564199
# NRO_138     2.218066             0.527901   0.582349   0.584191
# NRO_174     2.196258             0.491970   0.606018   0.601454
# NRO_190     2.274627             0.423661   0.596681   0.651538
# NRO_52      1.881607             0.621762   0.470569   0.586429
# NRO_O_56    2.055886             0.526352   0.531228   0.634192
# NRO_Y_82    2.176068             0.535951   0.562322   0.594887
# NRY_O_14    1.724199             0.655184   0.569986   0.494390
# NRY_O_20    1.651405             0.478338   0.583496   0.580246
# NRY_O_25    1.693007             0.372934   0.579344   0.648372
# NRY_Y_03    1.193234             0.519982   0.463610   0.553255
# NRY_Y_12    1.350274             0.683331   0.551412   0.486628
# NRY_Y_15    0.985114             0.656118   0.458109   0.439254
# PPO_O_05    2.241563             0.404994   0.630200   0.688433
# PPO_O_09    2.297022             0.353157   0.620963   0.717358
# PPO_Y_07    2.017280             0.228720   0.595616   0.789195
# PPO_Y_09    1.867705             0.557569   0.551658   0.580290
# PPO_Y_13    2.024940             0.332775   0.649515   0.720381
# PPO_Y_17    2.031744             0.407489   0.653776   0.640690
# PPY_O_09    1.807353             0.215783   0.593641   0.776392
# PPY_O_24    1.363957             0.501065   0.528755   0.570062
# PPY_O_31    2.007638             0.328032   0.661927   0.685228
# PPY_Y_01    1.163002             0.364616   0.509951   0.629125
# PPY_Y_22    1.540675             0.421399   0.613057   0.561466
# PPY_Y_23    0.784338             0.548339   0.403004   0.585329
# ULM_147     2.187851             0.554334   0.497091   0.606428
# ULM_27      1.983064             0.474949   0.501446   0.642486
# ULM_310     2.076267             0.596827   0.516628   0.553503
# ULM_325     2.281071             0.461572   0.532544   0.624186
# ULM_345     2.095967             0.424827   0.493417   0.652003
# ULM_80      2.213664             0.468071   0.562287   0.622972
# ULO_107     2.231605             0.417269   0.563471   0.674970
# ULO_139     2.083953             0.472925   0.521594   0.651416
# ULO_188     1.937726             0.430392   0.507908   0.676478
# ULO_237     1.974813             0.685291   0.500740   0.596380
# ULO_271     1.806537             0.591421   0.496393   0.634345
# ULY_Y_231   1.710456             0.952009   0.434663   0.430132
# ULY_Y_232   1.315641             0.825957   0.330515   0.442244
# ULY_Y_25    1.770590             0.928554   0.438510   0.459317
# ULY_Y_96    1.038298             0.733194   0.312615   0.458024
#
#            mean__veg_height_kurt    sd__chm   cv__chm  sd__canopy_cover_gt1m  \
# site
# EPO_O_04                0.187544  13.330358  0.348752               0.125496
# EPO_O_13                0.207591   6.769295  0.246819               0.203709
# EPO_Y_10                0.399777   5.477748  0.214736               0.193605
# EPO_Y_15               -0.691528   4.028354  0.204997               0.144095
# EPO_Y_36               -0.234955   4.098733  0.295683               0.197953
# EPO_Y_37               -0.231919   5.400514  0.284503               0.104405
# EPY_O_01                2.615524   3.348425  0.137875               0.161273
# EPY_O_07               -0.267701   3.608839  0.193783               0.120105
# EPY_O_09                1.688820   3.817097  0.236906               0.190139
# EPY_Y_03                0.368993   3.496191  0.420746               0.255072
# EPY_Y_04               -0.220785   2.365638  0.747488               0.271572
# EPY_Y_05               -0.125350   1.786667  0.327461               0.170116
# NRM_31                  0.166860   6.128783  0.301169               0.114687
# NRM_O_15               -0.638304   4.677869  0.276701               0.146446
# NRM_O_19               -0.580614   3.748231  0.158180               0.099206
# NRM_Y_39               -0.376265   4.591683  0.338734               0.118775
# NRM_Y_41               -0.283398   3.841554  0.223302               0.086997
# NRM_Y_69               -0.693503   3.670552  0.190833               0.073338
# NRO_138                -0.140781   7.470345  0.275386               0.109669
# NRO_174                -0.723778   3.857750  0.177105               0.069600
# NRO_190                -0.142454   6.485604  0.221705               0.058524
# NRO_52                  0.447948  11.851256  0.376098               0.136532
# NRO_O_56                0.038842   7.301614  0.222727               0.093419
# NRO_Y_82               -0.789654   4.979545  0.233034               0.125744
# NRY_O_14               -0.792125   2.968110  0.379302               0.201856
# NRY_O_20               -0.410863   2.576479  0.380251               0.187587
# NRY_O_25               -0.157742   2.239719  0.261571               0.141263
# NRY_Y_03                0.011789   2.339601  0.602242               0.291526
# NRY_Y_12               -0.356927   1.751777  0.400185               0.221260
# NRY_Y_15                0.095255   1.360831  0.581316               0.244890
# PPO_O_05                0.977032   5.195289  0.222622               0.178728
# PPO_O_09                2.634790   5.715140  0.197247               0.179223
# PPO_Y_07                2.748619   3.067664  0.142274               0.109721
# PPO_Y_09                0.157633   8.019559  0.534263               0.338172
# PPO_Y_13                1.225434   1.926172  0.120913               0.123305
# PPO_Y_17                0.416655   2.905519  0.214801               0.176669
# PPY_O_09                1.975334   1.987547  0.137168               0.118893
# PPY_O_24               -0.195083   2.685140  0.483675               0.309717
# PPY_O_31                0.828001   2.645194  0.197309               0.155100
# PPY_Y_01                0.983068   1.249156  0.313098               0.214916
# PPY_Y_22                0.372549   1.722775  0.319676               0.176945
# PPY_Y_23               -0.307468   1.241814  0.598295               0.286262
# ULM_147                 0.837654  22.266816  0.464693               0.121050
# ULM_27                  0.402965  12.082791  0.509178               0.168457
# ULM_310                 0.404399  14.335195  0.531888               0.165676
# ULM_325                 0.419146  17.304654  0.598880               0.101628
# ULM_345                 1.351378  16.605493  0.545628               0.125374
# ULM_80                  0.831308  10.818481  0.476908               0.148905
# ULO_107                 1.445625   8.357749  0.312223               0.137414
# ULO_139                 0.426490  10.434668  0.358333               0.132754
# ULO_188                 0.508593   8.345633  0.348567               0.189815
# ULO_237                -0.133164   8.790383  0.240575               0.166720
# ULO_271                 0.917677   5.465952  0.251930               0.197962
# ULY_Y_231               1.402636  14.996001  0.593612               0.265201
# ULY_Y_232               0.619507  14.471975  1.145557               0.271231
# ULY_Y_25                0.853794  17.079089  0.540517               0.204327
# ULY_Y_96                0.708619   5.370980  1.016634               0.285053
#
#             sd__vci   sd__fhd   sd__crr  sd__veg_height_skew site_type
# site
# EPO_O_04   0.114871  0.457687  0.167676             1.283775       EPO
# EPO_O_13   0.141558  0.520719  0.175375             1.208187       EPO
# EPO_Y_10   0.152311  0.538408  0.150632             1.099697       EPO
# EPO_Y_15   0.103413  0.346978  0.142027             0.930350       EPO
# EPO_Y_36   0.139617  0.430635  0.160847             1.122658       EPO
# EPO_Y_37   0.102920  0.354001  0.131940             0.901474       EPO
# EPY_O_01   0.132946  0.459745  0.128598             1.109719       EPY
# EPY_O_07   0.117699  0.392896  0.115948             0.733684       EPY
# EPY_O_09   0.134313  0.429018  0.153667             1.239037       EPY
# EPY_Y_03   0.196516  0.554030  0.165312             1.027402       EPY
# EPY_Y_04   0.215903  0.521382  0.162361             0.853857       EPY
# EPY_Y_05   0.147952  0.367328  0.100420             0.639126       EPY
# NRM_31     0.093482  0.338238  0.126822             0.923541       NRM
# NRM_O_15   0.121634  0.414435  0.122430             0.764254       NRM
# NRM_O_19   0.092752  0.329903  0.117170             0.779643       NRM
# NRM_Y_39   0.112578  0.373970  0.116519             0.792744       NRM
# NRM_Y_41   0.090051  0.311350  0.104132             0.817065       NRM
# NRM_Y_69   0.093979  0.314458  0.098670             0.626945       NRM
# NRO_138    0.105979  0.403612  0.131919             0.965233       NRO
# NRO_174    0.083656  0.303280  0.103260             0.660909       NRO
# NRO_190    0.105572  0.402816  0.110221             0.885765       NRO
# NRO_52     0.127213  0.508441  0.184457             1.326217       NRO
# NRO_O_56   0.106001  0.411756  0.146002             1.079995       NRO
# NRO_Y_82   0.091921  0.354793  0.114596             0.730816       NRO
# NRY_O_14   0.132107  0.400264  0.110052             0.702346       NRY
# NRY_O_20   0.119846  0.338853  0.117592             0.719139       NRY
# NRY_O_25   0.101768  0.296679  0.097543             0.788729       NRY
# NRY_Y_03   0.179644  0.462422  0.145121             0.912711       NRY
# NRY_Y_12   0.161023  0.393991  0.140704             0.897523       NRY
# NRY_Y_15   0.186551  0.401251  0.130059             0.752914       NRY
# PPO_O_05   0.149696  0.533834  0.127050             0.914847       PPO
# PPO_O_09   0.157001  0.580717  0.119182             1.030638       PPO
# PPO_Y_07   0.106442  0.360628  0.080261             1.047859       PPO
# PPO_Y_09   0.232243  0.786908  0.161952             1.028811       PPO
# PPO_Y_13   0.116379  0.362849  0.114178             0.843899       PPO
# PPO_Y_17   0.119405  0.370998  0.134621             0.783514       PPO
# PPY_O_09   0.094100  0.286489  0.081770             0.937323       PPY
# PPY_O_24   0.241850  0.623746  0.152957             0.760142       PPY
# PPY_O_31   0.119138  0.361400  0.107803             0.783319       PPY
# PPY_Y_01   0.162457  0.370646  0.132429             1.125505       PPY
# PPY_Y_22   0.118816  0.298789  0.102681             0.701313       PPY
# PPY_Y_23   0.238493  0.462176  0.189123             0.789402       PPY
# ULM_147    0.120913  0.532234  0.179879             1.351271       ULM
# ULM_27     0.130051  0.514664  0.149728             1.063762       ULM
# ULM_310    0.110552  0.444985  0.179611             1.189157       ULM
# ULM_325    0.123352  0.528297  0.140273             1.014601       ULM
# ULM_345    0.109290  0.464354  0.163178             1.298801       ULM
# ULM_80     0.110511  0.435631  0.154041             1.087230       ULM
# ULO_107    0.113326  0.449014  0.137637             1.108078       ULO
# ULO_139    0.113202  0.451802  0.142215             1.016343       ULO
# ULO_188    0.122186  0.465892  0.146293             1.121099       ULO
# ULO_237    0.113290  0.446818  0.153855             0.995417       ULO
# ULO_271    0.119513  0.433656  0.175958             1.285889       ULO
# ULY_Y_231  0.165052  0.649107  0.196310             1.531524       ULY
# ULY_Y_232  0.157922  0.629341  0.164692             1.237760       ULY
# ULY_Y_25   0.141006  0.569178  0.196590             1.462411       ULY
# ULY_Y_96   0.169496  0.563390  0.173973             1.160318       ULY

# %% [markdown]
# # Full Permanova
#
# Start with a PERMANOVA across all groups and all metrics

# %%
y = site_metrics['site_type']
X = site_metrics.drop(columns=['site_type'])

X.shape
# Out:
# (57, 16)

# %%
def get_p_val_group(p_val: float):
    if p_val < 0.001:
        significant = 'highly significant (p < 0.001)'
    elif p_val < 0.01:
        significant = 'very significant (p < 0.01)'
    elif p_val < 0.05:
        significant = 'significant (p < 0.05)'
    else:
        significant = 'not significant (p >= 0.5)'
    return significant

# %%
from scipy.stats import shapiro

stat, p = shapiro(X, axis=0)

shapiro_p_vals = pd.DataFrame(pd.Series(p, name='p_val', index=X.columns))
shapiro_p_vals['significant'] = shapiro_p_vals['p_val'] < 0.05
shapiro_p_vals
# Out:
#                             p_val  significant
# mean__chm                0.125858        False
# max__chm                 0.062499        False
# mean__veg_height_q30     0.103337        False
# mean__canopy_cover_gt1m  0.000004         True
# mean__fhd                0.000111         True
# mean__veg_height_cv      0.087825        False
# mean__vci                0.130403        False
# mean__crr                0.507277        False
# mean__veg_height_kurt    0.000758         True
# sd__chm                  0.000004         True
# cv__chm                  0.000004         True
# sd__canopy_cover_gt1m    0.036847         True
# sd__vci                  0.000014         True
# sd__fhd                  0.013792         True
# sd__crr                  0.617924        False
# sd__veg_height_skew      0.138951        False

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

distances = pdist(X_scaled, metric='euclidean')
distance_matrix = DistanceMatrix(squareform(distances), ids=y.index)

result = permanova(distance_matrix, y, permutations=9999)

print(f'Full PERMANOVA is {get_p_val_group(result['p-value'])}')

result
# Out:
# Full PERMANOVA is highly significant (p < 0.001)
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      57
# number of groups                 10
# test statistic             6.597396
# p-value                      0.0001
# number of permutations         9999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# ## Pairwise PERMANOVA

# %%
from itertools import combinations

def pair_wise_permanova(site_pair) -> pd.Series:
    site_a, site_b = site_pair
    mask = (y == site_a) | (y == site_b)

    y_mask = y[mask]
    dm_mask = distance_matrix.filter(y_mask.index)

    result = permanova(dm_mask, y_mask, permutations=9999)
    result.name = (site_a, site_b)
    return result

unique_sites = np.unique(y)
pair_combos = list(combinations(unique_sites, 2))

results = map(pair_wise_permanova, pair_combos)
permanova_df = pd.DataFrame(results)



permanova_df['p_val_group'] = permanova_df['p-value'].apply(get_p_val_group)
permanova_df
# Out:
#         method name test statistic name  sample size  number of groups  \
# EPO EPY   PERMANOVA            pseudo-F           12                 2
#     NRM   PERMANOVA            pseudo-F           12                 2
#     NRO   PERMANOVA            pseudo-F           12                 2
#     NRY   PERMANOVA            pseudo-F           12                 2
#     PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# EPY NRM   PERMANOVA            pseudo-F           12                 2
#     NRO   PERMANOVA            pseudo-F           12                 2
#     NRY   PERMANOVA            pseudo-F           12                 2
#     PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# NRM NRO   PERMANOVA            pseudo-F           12                 2
#     NRY   PERMANOVA            pseudo-F           12                 2
#     PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# NRO NRY   PERMANOVA            pseudo-F           12                 2
#     PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# NRY PPO   PERMANOVA            pseudo-F           12                 2
#     PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# PPO PPY   PERMANOVA            pseudo-F           12                 2
#     ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# PPY ULM   PERMANOVA            pseudo-F           12                 2
#     ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# ULM ULO   PERMANOVA            pseudo-F           11                 2
#     ULY   PERMANOVA            pseudo-F           10                 2
# ULO ULY   PERMANOVA            pseudo-F            9                 2
#
#          test statistic  p-value  number of permutations  \
# EPO EPY        2.648831   0.0500                    9999
#     NRM        6.871281   0.0024                    9999
#     NRO        2.948940   0.0535                    9999
#     NRY        7.200585   0.0018                    9999
#     PPO        4.121017   0.0117                    9999
#     PPY        4.342937   0.0022                    9999
#     ULM        7.653592   0.0070                    9999
#     ULO        3.178991   0.0216                    9999
#     ULY       10.773883   0.0048                    9999
# EPY NRM        4.567798   0.0088                    9999
#     NRO        4.554783   0.0036                    9999
#     NRY        1.811995   0.1603                    9999
#     PPO        1.496259   0.2139                    9999
#     PPY        0.418821   0.7142                    9999
#     ULM        7.776862   0.0020                    9999
#     ULO        3.324464   0.0250                    9999
#     ULY        7.096586   0.0087                    9999
# NRM NRO        3.215128   0.0428                    9999
#     NRY       10.883205   0.0020                    9999
#     PPO        5.062539   0.0024                    9999
#     PPY        4.966278   0.0076                    9999
#     ULM       21.499643   0.0019                    9999
#     ULO       13.621395   0.0015                    9999
#     ULY       31.630837   0.0054                    9999
# NRO NRY       11.767127   0.0021                    9999
#     PPO        3.975061   0.0019                    9999
#     PPY        5.942118   0.0022                    9999
#     ULM        6.644968   0.0109                    9999
#     ULO        2.915528   0.0620                    9999
#     ULY       18.380070   0.0051                    9999
# NRY PPO        7.101843   0.0041                    9999
#     PPY        1.171778   0.3046                    9999
#     ULM       21.435431   0.0023                    9999
#     ULO       13.356168   0.0029                    9999
#     ULY       11.852216   0.0052                    9999
# PPO PPY        2.372577   0.1101                    9999
#     ULM        6.794977   0.0020                    9999
#     ULO        2.699069   0.0268                    9999
#     ULY       11.986569   0.0046                    9999
# PPY ULM       10.225644   0.0027                    9999
#     ULO        5.147837   0.0084                    9999
#     ULY        8.222757   0.0095                    9999
# ULM ULO        3.545757   0.0083                    9999
#     ULY       12.887815   0.0054                    9999
# ULO ULY       13.938780   0.0062                    9999
#
#                          p_val_group
# EPO EPY   not significant (p >= 0.5)
#     NRM  very significant (p < 0.01)
#     NRO   not significant (p >= 0.5)
#     NRY  very significant (p < 0.01)
#     PPO       significant (p < 0.05)
#     PPY  very significant (p < 0.01)
#     ULM  very significant (p < 0.01)
#     ULO       significant (p < 0.05)
#     ULY  very significant (p < 0.01)
# EPY NRM  very significant (p < 0.01)
#     NRO  very significant (p < 0.01)
#     NRY   not significant (p >= 0.5)
#     PPO   not significant (p >= 0.5)
#     PPY   not significant (p >= 0.5)
#     ULM  very significant (p < 0.01)
#     ULO       significant (p < 0.05)
#     ULY  very significant (p < 0.01)
# NRM NRO       significant (p < 0.05)
#     NRY  very significant (p < 0.01)
#     PPO  very significant (p < 0.01)
#     PPY  very significant (p < 0.01)
#     ULM  very significant (p < 0.01)
#     ULO  very significant (p < 0.01)
#     ULY  very significant (p < 0.01)
# NRO NRY  very significant (p < 0.01)
#     PPO  very significant (p < 0.01)
#     PPY  very significant (p < 0.01)
#     ULM       significant (p < 0.05)
#     ULO   not significant (p >= 0.5)
#     ULY  very significant (p < 0.01)
# NRY PPO  very significant (p < 0.01)
#     PPY   not significant (p >= 0.5)
#     ULM  very significant (p < 0.01)
#     ULO  very significant (p < 0.01)
#     ULY  very significant (p < 0.01)
# PPO PPY   not significant (p >= 0.5)
#     ULM  very significant (p < 0.01)
#     ULO       significant (p < 0.05)
#     ULY  very significant (p < 0.01)
# PPY ULM  very significant (p < 0.01)
#     ULO  very significant (p < 0.01)
#     ULY  very significant (p < 0.01)
# ULM ULO  very significant (p < 0.01)
#     ULY  very significant (p < 0.01)
# ULO ULY  very significant (p < 0.01)

# %%
from statsmodels.stats.multitest import multipletests, multitest_methods_names

permanova_df['p-val-fdr_bh'] = multipletests(permanova_df['p-value'], method='fdr_bh')[1]
permanova_df['p-val-fdr_bg_group'] = permanova_df['p-val-fdr_bh'].apply(get_p_val_group)

# %%
permanova_df.reset_index().rename(columns= { "level_0": "site_type_a", "level_1": "site_type_b" }).to_csv("../csvs/pairwise-permanova-result.csv")

# %% [markdown]
# Pairwise permanova is ..
#
# ## Per metric analysis
#
# - Kruskall Wallis test to test amongs multiple groups
# - Post hoc dunns test to do pairwise

# %%
from scipy.stats import kruskal
import pandas as pd

# Perform Kruskal-Wallis test for each metric
kruskal_results = []

for metric in X.columns:
    # Group the metric values by site_type
    groups = [X.loc[y == site_type, metric].values for site_type in np.unique(y)]
    
    # Remove any groups that are empty or have insufficient data
    groups = [group for group in groups if len(group) > 0]
    
    if len(groups) >= 2:  # Need at least 2 groups for comparison
        # Perform Kruskal-Wallis test
        statistic, p_value = kruskal(*groups)
        
        kruskal_results.append({
            'metric': metric,
            'statistic': statistic,
            'p_value': p_value,
            'significant': 'Yes' if p_value < 0.05 else 'No',
            "p_val_group": get_p_val_group(p_value)
        })

# Convert to DataFrame
kruskal_df = pd.DataFrame(kruskal_results)
# kruskal_df = kruskal_df.sort_values('p_value')  # Sort by p-value
print(f"Kruskal-Wallis test results for {len(kruskal_df)} metrics:")
kruskal_df
# Out:
# Kruskal-Wallis test results for 16 metrics:
#                      metric  statistic       p_value significant  \
# 0                 mean__chm  36.018875  3.934200e-05         Yes
# 1                  max__chm  44.810224  1.000304e-06         Yes
# 2      mean__veg_height_q30  33.599335  1.049767e-04         Yes
# 3   mean__canopy_cover_gt1m  32.127465  1.892736e-04         Yes
# 4                 mean__fhd  30.379189  3.780671e-04         Yes
# 5       mean__veg_height_cv  30.305082  3.892370e-04         Yes
# 6                 mean__vci  26.262553  1.850314e-03         Yes
# 7                 mean__crr  27.337992  1.229534e-03         Yes
# 8     mean__veg_height_kurt  30.397157  3.754066e-04         Yes
# 9                   sd__chm  45.740956  6.726837e-07         Yes
# 10                  cv__chm  27.701875  1.069617e-03         Yes
# 11    sd__canopy_cover_gt1m  30.488990  3.620922e-04         Yes
# 12                  sd__vci  25.052329  2.913837e-03         Yes
# 13                  sd__fhd  23.374955  5.406942e-03         Yes
# 14                  sd__crr  25.326195  2.630760e-03         Yes
# 15      sd__veg_height_skew  29.154144  6.103596e-04         Yes
#
#                        p_val_group
# 0   highly significant (p < 0.001)
# 1   highly significant (p < 0.001)
# 2   highly significant (p < 0.001)
# 3   highly significant (p < 0.001)
# 4   highly significant (p < 0.001)
# 5   highly significant (p < 0.001)
# 6      very significant (p < 0.01)
# 7      very significant (p < 0.01)
# 8   highly significant (p < 0.001)
# 9   highly significant (p < 0.001)
# 10     very significant (p < 0.01)
# 11  highly significant (p < 0.001)
# 12     very significant (p < 0.01)
# 13     very significant (p < 0.01)
# 14     very significant (p < 0.01)
# 15  highly significant (p < 0.001)

# %%
import scikit_posthocs as sp

results = {}
flattenend_results = []

for metric in kruskal_df[kruskal_df['significant'] == 'Yes']['metric']:
    res = sp.posthoc_dunn(site_metrics, val_col=metric, group_col='site_type')
    results[metric] = res

    # Only take upper triangle to avoid duplicates (since matrix is symmetric)
    for i_idx, i in enumerate(res.index):
        for j_idx, j in enumerate(res.columns):
            if i_idx < j_idx:  # Only upper triangle (i_idx < j_idx avoids diagonal and lower triangle)
                flattenend_results.append({
                    "site_type_a": i,
                    "site_type_b": j,
                    "metric": metric,
                    "p_val": res.loc[i, j],
                    "p_val_group": get_p_val_group(res.loc[i, j] )
                })

flattenend_results = pd.DataFrame(flattenend_results)
flattenend_results.to_csv("../csvs/dunss_test_pairwise_per_metric.csv")
results['cv__chm']
# Out:
#           EPO       EPY       NRM       NRO       NRY       PPO       PPY  \
# EPO  1.000000  0.651131  0.767487  0.767487  0.051427  0.454548  0.519898
# EPY  0.651131  1.000000  0.454548  0.454548  0.134730  0.230122  0.848281
# NRM  0.767487  0.454548  1.000000  1.000000  0.024861  0.651131  0.347646
# NRO  0.767487  0.454548  1.000000  1.000000  0.024861  0.651131  0.347646
# NRY  0.051427  0.134730  0.024861  0.024861  1.000000  0.007023  0.192098
# PPO  0.454548  0.230122  0.651131  0.651131  0.007023  1.000000  0.164117
# PPY  0.519898  0.848281  0.347646  0.347646  0.192098  0.164117  1.000000
# ULM  0.011110  0.036885  0.004584  0.004584  0.554302  0.001012  0.057997
# ULO  0.537319  0.852660  0.368772  0.368772  0.214836  0.183544  0.997354
# ULY  0.003811  0.012813  0.001589  0.001589  0.249678  0.000368  0.020459
#
#           ULM       ULO       ULY
# EPO  0.011110  0.537319  0.003811
# EPY  0.036885  0.852660  0.012813
# NRM  0.004584  0.368772  0.001589
# NRO  0.004584  0.368772  0.001589
# NRY  0.554302  0.214836  0.249678
# PPO  0.001012  0.183544  0.000368
# PPY  0.057997  0.997354  0.020459
# ULM  1.000000  0.071202  0.533788
# ULO  0.071202  1.000000  0.025925
# ULY  0.533788  0.025925  1.000000

# %%
significant_results = flattenend_results[flattenend_results['p_val'] < 0.05]
significant_results
# Out:
#     site_type_a site_type_b               metric     p_val  \
# 3           EPO         NRY            mean__chm  0.003110
# 5           EPO         PPY            mean__chm  0.005109
# 10          EPY         NRO            mean__chm  0.008635
# 14          EPY         ULM            mean__chm  0.006665
# 15          EPY         ULO            mean__chm  0.012749
# ..          ...         ...                  ...       ...
# 709         NRY         ULY  sd__veg_height_skew  0.000326
# 713         PPO         ULY  sd__veg_height_skew  0.020459
# 714         PPY         ULM  sd__veg_height_skew  0.011110
# 715         PPY         ULO  sd__veg_height_skew  0.043754
# 716         PPY         ULY  sd__veg_height_skew  0.002296
#
#                         p_val_group
# 3       very significant (p < 0.01)
# 5       very significant (p < 0.01)
# 10      very significant (p < 0.01)
# 14      very significant (p < 0.01)
# 15           significant (p < 0.05)
# ..                              ...
# 709  highly significant (p < 0.001)
# 713          significant (p < 0.05)
# 714          significant (p < 0.05)
# 715          significant (p < 0.05)
# 716     very significant (p < 0.01)
#
# [241 rows x 5 columns]

# %%
from cliffs_delta import cliffs_delta

# Calculate Cliff's Delta for all significant results
sig_res_with_cliffs = []

for _, row in significant_results.iterrows():
    metric = row['metric']
    site_a = row['site_type_a']
    site_b = row['site_type_b']
    p_val = row['p_val']
    
    # Get the data for each group
    group_a_data = X.loc[y == site_a, metric].values
    group_b_data = X.loc[y == site_b, metric].values
    
    # Calculate Cliff's Delta
    delta, magnitude = cliffs_delta(group_a_data, group_b_data)
    
    sig_res_with_cliffs.append({
        'metric': metric,
        'site_type_a': site_a,
        'site_type_b': site_b,
        'p_val': p_val,
        'p_val_group': row['p_val_group'],
        'cliffs_delta': delta,
        'effect_size': magnitude,
        'mean_a': np.mean(group_a_data),
        'mean_b': np.mean(group_b_data),
        'n_a': len(group_a_data),
        'n_b': len(group_b_data)
    })
    
# Convert to DataFrame
cliffs_delta_df = pd.DataFrame(sig_res_with_cliffs)

# Sort by absolute effect size (largest effects first)
cliffs_delta_df['abs_cliffs_delta'] = abs(cliffs_delta_df['cliffs_delta'])
cliffs_delta_df = cliffs_delta_df.sort_values('abs_cliffs_delta', ascending=False)

cliffs_delta_df.to_csv("../csvs/significant_dunns_results_with_cliffs_delta.csv")
cliffs_delta_df.drop('abs_cliffs_delta', axis=1)
# Out:
#                     metric site_type_a site_type_b     p_val  \
# 0                mean__chm         EPO         NRY  0.003110
# 139                sd__chm         EPO         EPY  0.049380
# 122  mean__veg_height_kurt         EPO         ULM  0.041865
# 123  mean__veg_height_kurt         EPO         ULY  0.026643
# 127  mean__veg_height_kurt         NRM         ULM  0.002338
# ..                     ...         ...         ...       ...
# 218                sd__crr         NRO         ULM  0.049380
# 224                sd__crr         PPY         ULM  0.036885
# 67               mean__fhd         EPY         NRO  0.047403
# 111              mean__crr         EPY         NRY  0.047403
# 68               mean__fhd         EPY         ULM  0.045492
#
#                      p_val_group  cliffs_delta effect_size     mean_a  \
# 0    very significant (p < 0.01)      1.000000       large  24.144863
# 139       significant (p < 0.05)      1.000000       large   6.517501
# 122       significant (p < 0.05)     -1.000000       large  -0.060582
# 123       significant (p < 0.05)     -1.000000       large  -0.060582
# 127  very significant (p < 0.01)     -1.000000       large  -0.400871
# ..                           ...           ...         ...        ...
# 218       significant (p < 0.05)     -0.611111       large   0.131742
# 224       significant (p < 0.05)     -0.555556       large   0.127794
# 67        significant (p < 0.05)     -0.555556       large   1.683919
# 111       significant (p < 0.05)      0.500000       large   0.631968
# 68        significant (p < 0.05)     -0.500000       large   1.683919
#
#        mean_b  n_a  n_b
# 0    5.689086    6    6
# 139  3.070476    6    6
# 122  0.707808    6    6
# 123  0.896139    6    4
# 127  0.707808    6    6
# ..        ...  ...  ...
# 218  0.161118    6    6
# 224  0.161118    6    6
# 67   2.133752    6    6
# 111  0.533691    6    6
# 68   2.139647    6    6
#
# [241 rows x 11 columns]

# %%
import scikit_posthocs as sp

results = {}
flattenend_results = []

for metric in kruskal_df[kruskal_df['significant'] == 'Yes']['metric']:
    res = sp.posthoc_dunn(site_metrics, val_col=metric, group_col='site_type', p_adjust='holm')
    results[metric] = res

    # Only take upper triangle to avoid duplicates (since matrix is symmetric)
    for i_idx, i in enumerate(res.index):
        for j_idx, j in enumerate(res.columns):
            if i_idx < j_idx:  # Only upper triangle (i_idx < j_idx avoids diagonal and lower triangle)
                flattenend_results.append({
                    "site_type_a": i,
                    "site_type_b": j,
                    "metric": metric,
                    "p_val": res.loc[i, j],
                    "p_val_group": get_p_val_group(res.loc[i, j] )
                })

flattenend_results = pd.DataFrame(flattenend_results)
flattenend_results.to_csv("../csvs/dunss_test_pairwise_per_metric_holm.csv")
results['cv__chm']
# Out:
#           EPO       EPY       NRM       NRO       NRY       PPO       PPY  \
# EPO  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# EPY  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# NRM  1.000000  1.000000  1.000000  1.000000  0.845258  1.000000  1.000000
# NRO  1.000000  1.000000  1.000000  1.000000  0.845258  1.000000  1.000000
# NRY  1.000000  1.000000  0.845258  0.845258  1.000000  0.266872  1.000000
# PPO  1.000000  1.000000  1.000000  1.000000  0.266872  1.000000  1.000000
# PPY  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ULM  0.411062  1.000000  0.183366  0.183366  1.000000  0.044542  1.000000
# ULO  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ULY  0.156256  0.461255  0.068346  0.068346  1.000000  0.016544  0.716067
#
#           ULM       ULO       ULY
# EPO  0.411062  1.000000  0.156256
# EPY  1.000000  1.000000  0.461255
# NRM  0.183366  1.000000  0.068346
# NRO  0.183366  1.000000  0.068346
# NRY  1.000000  1.000000  1.000000
# PPO  0.044542  1.000000  0.016544
# PPY  1.000000  1.000000  0.716067
# ULM  1.000000  1.000000  1.000000
# ULO  1.000000  1.000000  0.845258
# ULY  1.000000  0.845258  1.000000

# %%
significant_results = flattenend_results[flattenend_results['p_val'] < 0.05]
significant_results
# Out:
#     site_type_a site_type_b                   metric     p_val  \
# 24          NRO         NRY                mean__chm  0.007067
# 26          NRO         PPY                mean__chm  0.012492
# 32          NRY         ULM                mean__chm  0.005081
# 33          NRY         ULO                mean__chm  0.013812
# 39          PPY         ULM                mean__chm  0.009108
# 40          PPY         ULO                mean__chm  0.023623
# 59          EPY         ULM                 max__chm  0.004855
# 69          NRO         NRY                 max__chm  0.023870
# 71          NRO         PPY                 max__chm  0.017001
# 77          NRY         ULM                 max__chm  0.000229
# 78          NRY         ULO                 max__chm  0.023335
# 84          PPY         ULM                 max__chm  0.000142
# 85          PPY         ULO                 max__chm  0.016887
# 120         NRY         PPO     mean__veg_height_q30  0.031852
# 122         NRY         ULM     mean__veg_height_q30  0.006590
# 123         NRY         ULO     mean__veg_height_q30  0.002479
# 145         EPY         NRO  mean__canopy_cover_gt1m  0.010207
# 149         EPY         ULM  mean__canopy_cover_gt1m  0.026318
# 159         NRO         NRY  mean__canopy_cover_gt1m  0.039014
# 164         NRO         ULY  mean__canopy_cover_gt1m  0.013938
# 178         ULM         ULY  mean__canopy_cover_gt1m  0.031819
# 229         EPO         PPO      mean__veg_height_cv  0.011175
# 230         EPO         PPY      mean__veg_height_cv  0.035281
# 241         EPY         ULY      mean__veg_height_cv  0.041068
# 263         PPO         ULY      mean__veg_height_cv  0.002606
# 266         PPY         ULY      mean__veg_height_cv  0.008059
# 293         NRM         ULY                mean__vci  0.005033
# 308         PPO         ULY                mean__vci  0.003734
# 353         PPO         ULY                mean__crr  0.003173
# 359         ULO         ULY                mean__crr  0.023571
# 379         NRM         PPO    mean__veg_height_kurt  0.016352
# 419         EPY         ULM                  sd__chm  0.006746
# 437         NRY         ULM                  sd__chm  0.000293
# 438         NRY         ULO                  sd__chm  0.036834
# 439         NRY         ULY                  sd__chm  0.011870
# 444         PPY         ULM                  sd__chm  0.000101
# 445         PPY         ULO                  sd__chm  0.017123
# 446         PPY         ULY                  sd__chm  0.005584
# 486         PPO         ULM                  cv__chm  0.044542
# 488         PPO         ULY                  cv__chm  0.016544
# 513         NRM         NRY    sd__canopy_cover_gt1m  0.035281
# 518         NRM         ULY    sd__canopy_cover_gt1m  0.009694
# 519         NRO         NRY    sd__canopy_cover_gt1m  0.028055
# 524         NRO         ULY    sd__canopy_cover_gt1m  0.007746
# 563         NRM         ULY                  sd__vci  0.045075
# 608         NRM         ULY                  sd__fhd  0.004830
# 653         NRM         ULY                  sd__crr  0.015590
# 698         NRM         ULY      sd__veg_height_skew  0.018203
# 709         NRY         ULY      sd__veg_height_skew  0.014688
#
#                         p_val_group
# 24      very significant (p < 0.01)
# 26           significant (p < 0.05)
# 32      very significant (p < 0.01)
# 33           significant (p < 0.05)
# 39      very significant (p < 0.01)
# 40           significant (p < 0.05)
# 59      very significant (p < 0.01)
# 69           significant (p < 0.05)
# 71           significant (p < 0.05)
# 77   highly significant (p < 0.001)
# 78           significant (p < 0.05)
# 84   highly significant (p < 0.001)
# 85           significant (p < 0.05)
# 120          significant (p < 0.05)
# 122     very significant (p < 0.01)
# 123     very significant (p < 0.01)
# 145          significant (p < 0.05)
# 149          significant (p < 0.05)
# 159          significant (p < 0.05)
# 164          significant (p < 0.05)
# 178          significant (p < 0.05)
# 229          significant (p < 0.05)
# 230          significant (p < 0.05)
# 241          significant (p < 0.05)
# 263     very significant (p < 0.01)
# 266     very significant (p < 0.01)
# 293     very significant (p < 0.01)
# 308     very significant (p < 0.01)
# 353     very significant (p < 0.01)
# 359          significant (p < 0.05)
# 379          significant (p < 0.05)
# 419     very significant (p < 0.01)
# 437  highly significant (p < 0.001)
# 438          significant (p < 0.05)
# 439          significant (p < 0.05)
# 444  highly significant (p < 0.001)
# 445          significant (p < 0.05)
# 446     very significant (p < 0.01)
# 486          significant (p < 0.05)
# 488          significant (p < 0.05)
# 513          significant (p < 0.05)
# 518     very significant (p < 0.01)
# 519          significant (p < 0.05)
# 524     very significant (p < 0.01)
# 563          significant (p < 0.05)
# 608     very significant (p < 0.01)
# 653          significant (p < 0.05)
# 698          significant (p < 0.05)
# 709          significant (p < 0.05)

# %%
# Calculate Cliff's Delta for all significant results
sig_res_with_cliffs = []

for _, row in significant_results.iterrows():
    metric = row['metric']
    site_a = row['site_type_a']
    site_b = row['site_type_b']
    p_val = row['p_val']
    
    # Get the data for each group
    group_a_data = X.loc[y == site_a, metric].values
    group_b_data = X.loc[y == site_b, metric].values
    
    # Calculate Cliff's Delta
    delta, magnitude = cliffs_delta(group_a_data, group_b_data)
    
    sig_res_with_cliffs.append({
        'metric': metric,
        'site_type_a': site_a,
        'site_type_b': site_b,
        'p_val': p_val,
        'p_val_group': row['p_val_group'],
        'cliffs_delta': delta,
        'effect_size': magnitude,
        'mean_a': np.mean(group_a_data),
        'mean_b': np.mean(group_b_data),
        'n_a': len(group_a_data),
        'n_b': len(group_b_data)
    })
    
# Convert to DataFrame
cliffs_delta_df = pd.DataFrame(sig_res_with_cliffs)

# Sort by absolute effect size (largest effects first)
cliffs_delta_df['abs_cliffs_delta'] = abs(cliffs_delta_df['cliffs_delta'])
cliffs_delta_df = cliffs_delta_df.sort_values('abs_cliffs_delta', ascending=False)

cliffs_delta_df.to_csv("../csvs/significant_dunns_results_with_cliffs_delta_holm.csv")
cliffs_delta_df.drop('abs_cliffs_delta', axis=1)
# Out:
#                      metric site_type_a site_type_b     p_val  \
# 0                 mean__chm         NRO         NRY  0.007067
# 35                  sd__chm         PPY         ULM  0.000101
# 25      mean__veg_height_cv         PPY         ULY  0.008059
# 26                mean__vci         NRM         ULY  0.005033
# 27                mean__vci         PPO         ULY  0.003734
# 28                mean__crr         PPO         ULY  0.003173
# 29                mean__crr         ULO         ULY  0.023571
# 31                  sd__chm         EPY         ULM  0.006746
# 32                  sd__chm         NRY         ULM  0.000293
# 33                  sd__chm         NRY         ULO  0.036834
# 34                  sd__chm         NRY         ULY  0.011870
# 36                  sd__chm         PPY         ULO  0.017123
# 23      mean__veg_height_cv         EPY         ULY  0.041068
# 37                  sd__chm         PPY         ULY  0.005584
# 39                  cv__chm         PPO         ULY  0.016544
# 41    sd__canopy_cover_gt1m         NRM         ULY  0.009694
# 42    sd__canopy_cover_gt1m         NRO         NRY  0.028055
# 43    sd__canopy_cover_gt1m         NRO         ULY  0.007746
# 44                  sd__vci         NRM         ULY  0.045075
# 45                  sd__fhd         NRM         ULY  0.004830
# 46                  sd__crr         NRM         ULY  0.015590
# 47      sd__veg_height_skew         NRM         ULY  0.018203
# 1                 mean__chm         NRO         PPY  0.012492
# 24      mean__veg_height_cv         PPO         ULY  0.002606
# 22      mean__veg_height_cv         EPO         PPY  0.035281
# 21      mean__veg_height_cv         EPO         PPO  0.011175
# 2                 mean__chm         NRY         ULM  0.005081
# 3                 mean__chm         NRY         ULO  0.013812
# 4                 mean__chm         PPY         ULM  0.009108
# 5                 mean__chm         PPY         ULO  0.023623
# 6                  max__chm         EPY         ULM  0.004855
# 7                  max__chm         NRO         NRY  0.023870
# 8                  max__chm         NRO         PPY  0.017001
# 9                  max__chm         NRY         ULM  0.000229
# 10                 max__chm         NRY         ULO  0.023335
# 11                 max__chm         PPY         ULM  0.000142
# 12                 max__chm         PPY         ULO  0.016887
# 13     mean__veg_height_q30         NRY         PPO  0.031852
# 14     mean__veg_height_q30         NRY         ULM  0.006590
# 15     mean__veg_height_q30         NRY         ULO  0.002479
# 16  mean__canopy_cover_gt1m         EPY         NRO  0.010207
# 17  mean__canopy_cover_gt1m         EPY         ULM  0.026318
# 19  mean__canopy_cover_gt1m         NRO         ULY  0.013938
# 20  mean__canopy_cover_gt1m         ULM         ULY  0.031819
# 48      sd__veg_height_skew         NRY         ULY  0.014688
# 40    sd__canopy_cover_gt1m         NRM         NRY  0.035281
# 30    mean__veg_height_kurt         NRM         PPO  0.016352
# 18  mean__canopy_cover_gt1m         NRO         NRY  0.039014
# 38                  cv__chm         PPO         ULM  0.044542
#
#                        p_val_group  cliffs_delta effect_size     mean_a  \
# 0      very significant (p < 0.01)      1.000000       large  27.406963
# 35  highly significant (p < 0.001)     -1.000000       large   1.921938
# 25     very significant (p < 0.01)     -1.000000       large   0.396539
# 26     very significant (p < 0.01)      1.000000       large   0.619787
# 27     very significant (p < 0.01)      1.000000       large   0.616954
# 28     very significant (p < 0.01)      1.000000       large   0.689391
# 29          significant (p < 0.05)      1.000000       large   0.646718
# 31     very significant (p < 0.01)     -1.000000       large   3.070476
# 32  highly significant (p < 0.001)     -1.000000       large   2.206086
# 33          significant (p < 0.05)     -1.000000       large   2.206086
# 34          significant (p < 0.05)     -1.000000       large   2.206086
# 36          significant (p < 0.05)     -1.000000       large   1.921938
# 23          significant (p < 0.05)     -1.000000       large   0.460430
# 37     very significant (p < 0.01)     -1.000000       large   1.921938
# 39          significant (p < 0.05)     -1.000000       large   0.238687
# 41     very significant (p < 0.01)     -1.000000       large   0.106575
# 42          significant (p < 0.05)     -1.000000       large   0.098915
# 43     very significant (p < 0.01)     -1.000000       large   0.098915
# 44          significant (p < 0.05)     -1.000000       large   0.100746
# 45     very significant (p < 0.01)     -1.000000       large   0.347059
# 46          significant (p < 0.05)     -1.000000       large   0.114290
# 47          significant (p < 0.05)     -1.000000       large   0.784032
# 1           significant (p < 0.05)      1.000000       large  27.406963
# 24     very significant (p < 0.01)     -1.000000       large   0.380784
# 22          significant (p < 0.05)      1.000000       large   0.662658
# 21          significant (p < 0.05)      1.000000       large   0.662658
# 2      very significant (p < 0.01)     -1.000000       large   5.689086
# 3           significant (p < 0.05)     -1.000000       large   5.689086
# 4      very significant (p < 0.01)     -1.000000       large   7.536912
# 5           significant (p < 0.05)     -1.000000       large   7.536912
# 6      very significant (p < 0.01)     -1.000000       large  19.160233
# 7           significant (p < 0.05)      1.000000       large  44.445133
# 8           significant (p < 0.05)      1.000000       large  44.445133
# 9   highly significant (p < 0.001)     -1.000000       large  13.529967
# 10          significant (p < 0.05)     -1.000000       large  13.529967
# 11  highly significant (p < 0.001)     -1.000000       large  12.419767
# 12          significant (p < 0.05)     -1.000000       large  12.419767
# 13          significant (p < 0.05)     -1.000000       large   2.206013
# 14     very significant (p < 0.01)     -1.000000       large   2.206013
# 15     very significant (p < 0.01)     -1.000000       large   2.206013
# 16          significant (p < 0.05)     -1.000000       large   0.592883
# 17          significant (p < 0.05)     -1.000000       large   0.592883
# 19          significant (p < 0.05)      1.000000       large   0.908020
# 20          significant (p < 0.05)      1.000000       large   0.898148
# 48          significant (p < 0.05)     -1.000000       large   0.795560
# 40          significant (p < 0.05)     -0.944444       large   0.106575
# 30          significant (p < 0.05)     -0.944444       large  -0.400871
# 18          significant (p < 0.05)      0.944444       large   0.908020
# 38          significant (p < 0.05)     -0.777778       large   0.238687
#
#        mean_b  n_a  n_b
# 0    5.689086    6    6
# 35  15.568905    6    6
# 25   0.859929    6    4
# 26   0.379076    6    4
# 27   0.379076    6    4
# 28   0.447429    6    4
# 29   0.447429    5    4
# 31  15.568905    6    6
# 32  15.568905    6    6
# 33   8.278877    6    5
# 34  12.979511    6    4
# 36   8.278877    6    5
# 23   0.859929    6    4
# 37  12.979511    6    4
# 39   0.824080    6    4
# 41   0.256453    6    4
# 42   0.214731    6    6
# 43   0.256453    6    4
# 44   0.158369    6    4
# 45   0.602754    6    4
# 46   0.182892    6    4
# 47   1.348003    6    4
# 1    7.536912    6    6
# 24   0.859929    6    4
# 22   0.396539    6    6
# 21   0.380784    6    6
# 2   30.393876    6    6
# 3   27.871228    6    5
# 4   30.393876    6    6
# 5   27.871228    6    5
# 6   62.412967    6    6
# 7   13.529967    6    6
# 8   12.419767    6    6
# 9   62.412967    6    6
# 10  46.513360    6    5
# 11  62.412967    6    6
# 12  46.513360    6    5
# 13  12.551844    6    6
# 14  13.834872    6    6
# 15  14.273998    6    5
# 16   0.908020    6    6
# 17   0.898148    6    6
# 19   0.510249    6    4
# 20   0.510249    6    4
# 48   1.348003    6    4
# 40   0.214731    6    6
# 30   1.360027    6    6
# 18   0.611700    6    6
# 38   0.521196    6    6
