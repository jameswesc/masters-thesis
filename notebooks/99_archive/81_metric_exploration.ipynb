# %%
import xarray as xr

# %%
ds = xr.load_dataset('../data/outputs/plots/metrics/metrics_grid_1m_z_1m.nc')
ds
# Out:
# <xarray.Dataset> Size: 29GB
# Dimensions:             (plot: 315, x: 79, y: 82, z: 108)
# Coordinates:
#   * x                   (x) float64 632B 0.0 1.0 2.0 3.0 ... 75.0 76.0 77.0 78.0
#   * y                   (y) float64 656B 0.0 1.0 2.0 3.0 ... 78.0 79.0 80.0 81.0
#   * z                   (z) float64 864B 0.0 1.0 2.0 3.0 ... 105.0 106.0 107.0
#   * plot                (plot) <U12 15kB 'AGG_O_01_P1' ... 'ULY_Y_96_P5'
#     site                (plot) <U9 11kB 'AGG_O_01' 'AGG_O_01' ... 'ULY_Y_96'
#     site_type           (plot) <U3 4kB 'AGG' 'AGG' 'AGG' ... 'ULY' 'ULY' 'ULY'
# Data variables: (12/51)
#     max_veg             (plot, x, y) float64 16MB nan nan nan ... nan nan nan
#     mean_veg            (plot, x, y) float64 16MB nan nan nan ... nan nan nan
#     median_veg          (plot, x, y) float64 16MB nan nan nan ... nan nan nan
#     sd_veg              (plot, x, y) float64 16MB nan nan nan ... nan nan nan
# ...

# %%
ds.sel(plot='AGG_O_01_P1')['lcover'].plot()
