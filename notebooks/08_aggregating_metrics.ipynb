# %% [markdown]
# # Aggregating and combining metrics
#
# The plot metrics we previously created can be 0D (single value), 1D (vertical profile), 2D (single values across an xy grid) or 3D (vertical profiles across an xy grid - ie. voxels).
#
# At the moment, to compare plots we just want 0D metrics.
#
# For the non gridded metrics, we've already calculated some summary stats over the vertical profiles, so we can just drop those metrics / data_vars. Similarly, we can drop the vertical profiles in the gridded metrics to just have 2D metrics. Now we can summarise across the x and y dimensions using something like sd or cv to capture variability.
#
# Not using open_mfdataset this time because it seems to be very slow.

# %%
from pathlib import Path

import geopandas as gpd
import pandas as pd
import numpy as np
import xarray as xr

# %%
data_dir = Path("../data")
plots_dir = data_dir / "outputs" / "plots"
metrics_dir = plots_dir / "metrics"
lidar_dir = plots_dir / "lidar"

# %%
def drop_z_data_vars(ds):
    vars_without_z = [v for v in ds.data_vars if "z" not in ds[v].dims]
    ds = ds[vars_without_z]
    return ds


def read_metrics(plot: str, subdir="no_grid_z_1m"):
    path = metrics_dir / subdir / f"{plot}.nc"
    with xr.open_dataset(path) as ds:
        return ds.load()


def ds_to_df(ds, grid_size=0):
    ds = drop_z_data_vars(ds)

    if grid_size > 0:
        ds_mean = ds.mean(dim=["x", "y"])
        ds_std = ds.std(dim=["x", "y"])
        ds_cv = ds_std / ds_mean

        df_mean = ds_mean.stack(plot_variant=("plot", "variant")).to_dataframe()
        df_std = ds_std.stack(plot_variant=("plot", "variant")).to_dataframe()
        df_cv = ds_cv.stack(plot_variant=("plot", "variant")).to_dataframe()

        df_mean["grid_agg"] = "mean"
        df_std["grid_agg"] = "std"
        df_cv["grid_agg"] = "cv"
        df = pd.concat([df_mean, df_std, df_cv])
    else:
        df = ds.stack(plot_variant=("plot", "variant")).to_dataframe()
        df["grid_agg"] = 'none'

    df["grid_size"] = grid_size

    # Drop the plot_variant multi-index
    df = df.reset_index(drop=True)
    df = df.set_index("plot")

    return df


def load_df_for_grid_size(plot: str, grid_size=0):
    if grid_size == 0:
        ds = read_metrics(plot, "no_grid_z_1m")
    elif grid_size == 10:
        ds = read_metrics(plot, "grid_10m_z_1m")
    elif grid_size == 5:
        ds = read_metrics(plot, "grid_5m_z_1m")
    elif grid_size == 1:
        ds = read_metrics(plot, "grid_1m_z_1m")
    else:
        raise ValueError(f"Grid size {grid_size} not supported")

    return ds_to_df(ds, grid_size)


def load_plot_metrics(plot: str):
    df_no_grid = load_df_for_grid_size(plot, 0)
    df_grid_10m = load_df_for_grid_size(plot, 10)
    df_grid_5m = load_df_for_grid_size(plot, 5)
    df_grid_1m = load_df_for_grid_size(plot, 1)

    return pd.concat([df_no_grid, df_grid_10m, df_grid_5m, df_grid_1m])

# %%
plots = gpd.read_file(plots_dir / "plots.geojson")
plot_ids = plots['id'].to_list()

# %%
from dask.distributed import Client

client = Client()  # Start a Dask client
client
# Out:
# <Client: 'tcp://127.0.0.1:60262' processes=4 threads=8, memory=16.00 GiB>
# 2025-08-15 17:58:19,485 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 17:58:22,588 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:60274' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'EPO_Y_36_P4', 'AGG_Y_04_P4', 'EPO_Y_15_P5', 'AGG_O_05_P1', 'EPO_Y_37_P3', 'EPO_Y_10_P2', 'AGG_O_07_P4', 'EPO_Y_15_P1', 'EPY_O_01_P2', 'EPO_Y_36_P1', 'EPO_O_13_P1', 'EPO_Y_37_P4', 'EPY_O_01_P5', 'AGG_Y_03_P4', 'AGG_Y_03_P2', 'EPO_O_04_P2', 'AGG_O_05_P5', 'AGG_Y_04_P3', 'EPO_O_13_P5', 'AGG_Y_02_P3'} (stimulus_id='handle-worker-cleanup-1755244702.587997')
# 2025-08-15 17:58:22,722 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 17:58:31,400 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:60298' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'ULM_310_P2', 'NRM_Y_39_P1', 'ULY_Y_25_P3', 'EPO_Y_36_P4', 'PPY_Y_22_P4', 'AGG_Y_04_P4', 'ULY_Y_232_P4', 'EPO_Y_15_P5', 'NRM_O_15_P5', 'PPY_O_31_P2', 'EPO_Y_10_P3', 'AGG_O_05_P1', 'NRM_31_P4', 'EPO_Y_37_P3', 'EPY_Y_03_P1', 'NRM_Y_39_P5', 'NRO_O_56_P2', 'EPO_Y_15_P3', 'NRY_Y_03_P3', 'PPY_O_09_P4', 'ULO_107_P4', 'NRY_O_20_P5', 'EPO_O_13_P3', 'ULO_139_P3', 'ULO_188_P2', 'EPY_O_07_P3', 'ULM_345_P4', 'NRO_190_P5', 'NRM_Y_69_P5', 'NRO_174_P1', 'EPY_O_09_P5', 'NRM_Y_41_P2', 'AGG_O_07_P4', 'EPY_O_01_P3', 'EPO_Y_15_P1', 'NRY_Y_03_P1', 'EPY_O_01_P2', 'ULM_345_P2', 'EPO_Y_36_P1', 'ULM_80_P5', 'PPO_O_09_P2', 'EPO_O_13_P1', 'EPO_Y_37_P4', 'NRO_174_P5', 'EPO_O_13_P2', 'AGG_Y_03_P4', 'PPY_O_24_P4', 'AGG_Y_03_P2', 'PPO_Y_13_P3', 'ULM_310_P4', 'EPO_O_04_P2', 'AGG_O_05_P5', 'AGG_Y_04_P3', 'AGG_Y_04_P1', 'NRY_Y_15_P3', 'ULM_27_P5', 'PPO_Y_17_P5', 'PPO_Y_13_P2', 'NRM_O_15_P3', 'NRO_52_P4', 'EPO_O_13_P5', 'NRY_O_20_P3', 'NRY_O_14_P4', 'EPY_O_09_P4', 'AGG_Y_02_P3', 'NRY_O_25_P2'} (stimulus_id='handle-worker-cleanup-1755244711.400346')
# 2025-08-15 17:58:31,482 - distributed.nanny - WARNING - Restarting worker

# %%
futures = client.map(load_plot_metrics, plot_ids, key=plot_ids, retries=10)

# %%
results = client.gather(futures)

# %%
df = pd.concat(results)
df
# Out:
#                    max       min      range      mean    median        sd  \
# plot
# AGG_O_01_P1  16.275999  0.000000  16.275999  4.428016  4.555000  4.093416
# AGG_O_01_P1  16.275999  0.000000  16.275999  6.716327  7.568000  3.647536
# AGG_O_01_P1  16.275999  0.000000  16.275999  4.428016  4.555000  4.093416
# AGG_O_01_P1  16.275999  0.000000  16.275999  4.428016  4.555000  4.093416
# AGG_O_01_P1  16.275999  0.001000  16.275000  5.646877  6.400000  3.805994
# ...                ...       ...        ...       ...       ...       ...
# ULY_Y_96_P5   1.277456  6.454628   1.294826  1.519432  2.150591  1.458456
# ULY_Y_96_P5   1.273690  8.157261   1.284342  1.545650  2.531208  1.467207
# ULY_Y_96_P5   1.273690  8.157261   1.284342  1.545650  2.531208  1.467207
# ULY_Y_96_P5   1.266414  3.705982   1.307232  1.437641  2.025826  1.486969
# ULY_Y_96_P5   1.200145  1.982114   1.420801  1.314224  1.571348  1.549403
#
#                    var        cv       crr      skew  ...  norm_fhd  \
# plot                                                  ...
# AGG_O_01_P1  16.756056  0.924436  0.272058  0.245465  ...  0.824705
# AGG_O_01_P1  13.304515  0.543085  0.412652 -0.601755  ...  0.860111
# AGG_O_01_P1  16.756056  0.924436  0.272058  0.245465  ...  0.821678
# AGG_O_01_P1  16.756056  0.924436  0.272058  0.245465  ...  0.811571
# AGG_O_01_P1  14.485587  0.674000  0.346905 -0.170667  ...  0.838153
# ...                ...       ...       ...       ...  ...       ...
# ULY_Y_96_P5   3.106510  0.608595  0.484396  1.262774  ...  0.240840
# ULY_Y_96_P5   3.153993  0.567536  0.486007  1.016162  ...  0.247022
# ULY_Y_96_P5   3.153993  0.567536  0.486007  1.016162  ...  0.276168
# ULY_Y_96_P5   3.204246  0.529988  0.371274  1.538131  ...  0.311155
# ULY_Y_96_P5   3.332978  0.783563  0.335469  2.958102  ...  0.202523
#
#              cv_inside  cv_inside_p    cv_ppi    cv_vad      site  site_type  \
# plot
# AGG_O_01_P1   1.051162     1.051162  0.111321  1.511392  AGG_O_01        AGG
# AGG_O_01_P1   0.848656     0.848656  0.129149  0.997475  AGG_O_01        AGG
# AGG_O_01_P1   1.066437     1.066437  0.110900  1.522600  AGG_O_01        AGG
# AGG_O_01_P1   1.125259     1.125259  0.109713  1.573446  AGG_O_01        AGG
# AGG_O_01_P1   0.972110     0.972110  0.070207  0.761257  AGG_O_01        AGG
# ...                ...          ...       ...       ...       ...        ...
# ULY_Y_96_P5   0.448943     0.448943  0.698109  0.622618  ULY_Y_96        ULY
# ULY_Y_96_P5   0.454578     0.454578  0.714566  0.606891  ULY_Y_96        ULY
# ULY_Y_96_P5   0.468649     0.468649  0.728377  0.601008  ULY_Y_96        ULY
# ULY_Y_96_P5   0.381923     0.381923  0.865285  0.634225  ULY_Y_96        ULY
# ULY_Y_96_P5   0.493307     0.493307  0.655292  0.618493  ULY_Y_96        ULY
#
#              variant  grid_agg  grid_size
# plot
# AGG_O_01_P1  default      none          0
# AGG_O_01_P1      rnw      none          0
# AGG_O_01_P1       iw      none          0
# AGG_O_01_P1       fr      none          0
# AGG_O_01_P1       v0      none          0
# ...              ...       ...        ...
# ULY_Y_96_P5      rnw        cv          1
# ULY_Y_96_P5       iw        cv          1
# ULY_Y_96_P5       fr        cv          1
# ULY_Y_96_P5       v0        cv          1
# ULY_Y_96_P5      v05        cv          1
#
# [18900 rows x 40 columns]

# %%
df.to_csv(plots_dir /  "plot_metrics.csv")
df.to_parquet(plots_dir / "plot_metrics.parquet")
df.to_json(plots_dir / "plot_metrics.json", orient='records')

# %%
client.close()
